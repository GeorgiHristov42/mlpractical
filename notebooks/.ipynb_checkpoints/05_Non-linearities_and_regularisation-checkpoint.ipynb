# %% [markdown]
# # Regularisation
#
# In this lab we will explore different methods for regularising networks to reduce overfitting and improve generalisation. This uses the material covered in the [fifth lecture slides](http://www.inf.ed.ac.uk/teaching/courses/mlp/2016/mlp05-hid.pdf).

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# # Exercise 1: L1 and L2 penalties
#
# In the previous lab notebook we explored the issue of overfitting. There we saw that this arises when the model is 'too complex' ($\sim$ has too many degrees of freedom / parameters) for the amount of data we have available.
#
# One method for trying to reduce overfitting is therefore to try to decrease the flexibility of the model. We can do this by simply reducing the number of free parameters in the model (e.g. by using a shallower model with fewer layers or layers with smaller dimensionality). More generally however we might want some way of more continuously varying the effective flexibility of a model with a fixed architecture.
#
# A common method for doing this is to add an additional term to the objective function being minimised during training which penalises some measure of the complexity of a model as a function of the model parameters. The aim of training is then to minimise with respect to the model parameters the sum $E^\star$ of the data-driven error function term $\bar{E}$ and a model complexity term $C$.
#
# \begin{equation}
#    E^\star =
#    \underbrace{\bar{E}}_{\textrm{data term}} + \underbrace{C}_{\textrm{complexity term}}
# \end{equation}
#
# We need the complexity term $C$ to be easy to compute and differentiable with respect to the model parameters. A common choice is to use terms involving the *norms* ($\sim$ a measure of size) of the parameters. This penalises models with large parameter values. Two commonly used norms are the L1 and L2 norms.
#
# For a $D$ dimensional vector $\mathbf{v}$ the L1 norm is defined as
#
# \begin{equation}
# \| \boldsymbol{v} \|_1 = \sum_{d=1}^D \left| v_d \right|,
# \end{equation}
#
# and the L2 norm is defined as
#
# \begin{equation}
# \| \boldsymbol{v} \|_2 = \left[ \sum_{d=1}^D \left( v_d^2 \right) \right]^{\frac{1}{2}}.
# \end{equation}
#
# For a $K \times D$ matrix $\mathbf{M}$, we will define norms by collapsing the matrix to a vector $\boldsymbol{m} = \mathrm{vec}\left[\mathbf{M}\right] = \left[ M_{1,1} \dots M_{1,D} ~ M_{2,1} \dots M_{K,D} \right]^{\rm T}$ and then taking the norm as defined above of this resulting vector (practically this just results in summing over two sets of indices rather than one).
#
# The overall complexity penalty term $C$ is defined as a sum over individual complexity terms for each of the $P$ parameters of the model
#
# \begin{equation}
#     C = \sum_{i=1}^P \left[ C^{(i)} \right]
# \end{equation}
#
# Some of these per-parameter penalty terms $C^{(i)}$ may be set to zero if we do not wish to penalise the size of the corresponding parameter.
#
# To enable us to tradeoff between the model complexity and data error terms, it is typical to introduce positive scalar coefficients $\beta_i$ to scale the penalty term on the $i$th parameter. A *L1 penalty* on the $i$th vector parameter $\boldsymbol{p}^{(i)}$ (or matrix parameter collapsed to a vector) is then commonly defined as
#
# \begin{equation}
#   C^{(i)}_{\textrm{L1}} =
#   \beta_i \left\| \boldsymbol{p}^{(i)} \right\|_1 =
#   \beta_i  \sum_{d=1}^D \left| p^{(i)}_d \right|.
# \end{equation}
#
# This has a gradient with respect to the parameter vector
#
# \begin{equation}
#   \frac{\partial C^{(i)}_{\textrm{L1}}}{\partial p^{(i)}_d} = \beta_i \, \textrm{sgn}\left( p^{(i)}_d \right)
# \end{equation}
#
# where $\textrm{sgn}(u) = +1$ if $u > 0$, $\textrm{sgn}(u) = -1$ if $u < 0$ (and is not well defined for $u=0$ though a common convention is to have $\textrm{sgn}(0) = 0$).
#
# Similarly a *L2 penalty* on the $i$th vector parameter $\boldsymbol{p}^{(i)}$ (or matrix parameter collapsed to a vector) is commonly defined as
#
# \begin{equation}
#   C^{(i)}_{\textrm{L2}} =
#   \frac{1}{2} \beta_i \left\| \boldsymbol{p}^{(i)} \right\|_2^2 =
#   \frac{1}{2} \beta_i \sum_{d=1}^D \left[ \left( p^{(i)}_d \right)^2 \right].
# \end{equation}
#
# Somewhat confusingly this is proportional to the square of the L2 norm rather than the L2 norm itself, however it is an almost universal convention to call this an L2 penalty so we will stick with this nomenclature here. The $\frac{1}{2}$ term is less universal and is sometimes not included; we include it here for consistency with how we defined the sum of squared errors cost. Similarly to that case, the $\frac{1}{2}$ cancels when calculating the gradient with respect to the parameter
#
# \begin{equation}
#   \frac{\partial C^{(i)}_{\textrm{L2}}}{\partial p^{(i)}_d} = \beta_i p^{(i)}_d
# \end{equation}
#
# Use the above definitions for the L1 and L2 penalties for a parameter and corresponding gradients to implement the `__call__` and `grad` methods respectively for the skeleton `L1Penalty` and `L2Penalty` class definitions below. The `coefficient` propert of these classes should be used as the $\beta_i$ value in the equations above. The parameter the penalty term (or gradient) is being evaluated for will be either a one or two-dimensional NumPy array (corresponding to a vector or matrix parameter respectively) and your implementations should be able to cope with both cases.

# %%
import numpy as np
seed = 22102017 
rng = np.random.RandomState(seed)
class L1Penalty(object):
    """L1 parameter penalty.
    
    Term to add to the objective function penalising parameters
    based on their L1 norm.
    """
    
    def __init__(self, coefficient):
        """Create a new L1 penalty object.
        
        Args:
            coefficient: Positive constant to scale penalty term by.
        """
        assert coefficient > 0., 'Penalty coefficient must be positive.'
        self.coefficient = coefficient
        
    def __call__(self, parameter):
        """Calculate L1 penalty value for a parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty term.
        """
        pen = self.coefficient * sum(abs(parameter))
        return np.sum(pen)
        
    def grad(self, parameter):
        """Calculate the penalty gradient with respect to the parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty gradient with respect to parameter. This
            should be an array of the same shape as the parameter.
        """
        return self.coefficient * np.sign(parameter)
    
    def __repr__(self):
        return 'L1Penalty({0})'.format(self.coefficient)
        

class L2Penalty(object):
    """L1 parameter penalty.
    
    Term to add to the objective function penalising parameters
    based on their L2 norm.
    """

    def __init__(self, coefficient):
        """Create a new L2 penalty object.
        
        Args:
            coefficient: Positive constant to scale penalty term by.
        """
        assert coefficient > 0., 'Penalty coefficient must be positive.'
        self.coefficient = coefficient
        
    def __call__(self, parameter):
        """Calculate L2 penalty value for a parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty term.
        """
        
        params = (self.coefficient * np.sum(parameter ** 2))/2
        return np.sum(params)
        
    def grad(self, parameter):
        """Calculate the penalty gradient with respect to the parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty gradient with respect to parameter. This
            should be an array of the same shape as the parameter.
        """
        return self.coefficient * parameter
    
    def __repr__(self):
        return 'L2Penalty({0})'.format(self.coefficient)

# %% [markdown]
# Test your implementations by running the cells below.

# %%
test_params_1 = np.array([[0.5, 0.3, -1.2, 5.8], [0.2, -3.1, 4.9, -5.0]])
test_params_2 = np.array([0.8, -0.6, -0.3, 1.5, 2.8])
true_l1_cost_1 = 10.5
true_l1_grad_1 = np.array([[0.5, 0.5, -0.5, 0.5], [0.5, -0.5, 0.5, -0.5]])
true_l1_cost_2 = 3.
true_l1_grad_2 = np.array([0.5, -0.5, -0.5, 0.5, 0.5])
l1 = L1Penalty(0.5)
if (not np.allclose(l1(test_params_1), true_l1_cost_1) or
        not np.allclose(l1(test_params_2), true_l1_cost_2)):
    print('L1Penalty.__call__ giving incorrect value(s).')
elif (not np.allclose(l1.grad(test_params_1), true_l1_grad_1) or 
          not np.allclose(l1.grad(test_params_2), true_l1_grad_2)):
    print('L1Penalty.grad giving incorrect value(s).')
else:
    print('All test values calculated correctly for L1Penalty')
# Out:
# All test values calculated correctly for L1Penalty

# %%
test_params_1 = np.array([[0.5, 0.3, -1.2, 5.8], [0.2, -3.1, 4.9, -5.0]])
test_params_2 = np.array([0.8, -0.6, -0.3, 1.5, 2.8])
true_l2_cost_1 = 23.52
true_l2_grad_1 = np.array([[0.25, 0.15, -0.6, 2.9], [0.1, -1.55, 2.45, -2.5]])
true_l2_cost_2 = 2.795
true_l2_grad_2 = np.array([0.4, -0.3, -0.15, 0.75, 1.4])
l2 = L2Penalty(0.5)
if (not np.allclose(l2(test_params_1), true_l2_cost_1) or
        not np.allclose(l2(test_params_2), true_l2_cost_2)):
    print('L2Penalty.__call__ giving incorrect value(s).')
elif (not np.allclose(l2.grad(test_params_1), true_l2_grad_1) or 
          not np.allclose(l2.grad(test_params_2), true_l2_grad_2)):
    print('L2Penalty.grad giving incorrect value(s).')
else:
    print('All test values calculated correctly for L2Penalty')
# Out:
# All test values calculated correctly for L2Penalty

# %% [markdown]
# ## Exercise 2: Training with regularisation

# %% [markdown]
# Previously in the second laboratory you implemented a function `grads_wrt_params`  to calculate the gradient of an error function with respect to the parameters of an affine model (layer), given gradients of the error function with respect to the model (layer) outputs.
#
# If we are training a model using a regularised objective function, we need to additionally calculate the gradients of the regularisation penalty terms with respect to the parameters and add these to the error function gradient terms. Following from the definition of the regularised objective $E^\star$ above we have that the gradient of the overall objective with respect to the $d$th element of the $i$th model parameter is
#
# \begin{equation}
#     \frac{\partial E^\star}{\partial p^{(i)}_d} =
#     \frac{\partial \bar{E}}{\partial p^{(i)}_d} +
#     \frac{\partial C}{\partial p^{(i)}_d}
# \end{equation}
#
# We have already discussed in the second lab notebook how to calculate the error function gradient term $\frac{\partial \bar{E}}{\partial p^{(i)}_d}$. As the model complexity term is composed of a sum of per parameter terms and only one of these will depend on the $i$th parameter we can write
#
# \begin{equation}
#     \frac{\partial C}{\partial p^{(i)}_d} = \frac{\partial C^{(i)}}{\partial p^{(i)}_d}
# \end{equation}
#
# which corresponds to the penalty term gradients you implemented above. To enable us to use the same `Optimiser` implementation that we have previously used to train models without regularisation, we have altered the implementation of the `AffineLayer` class (this being the only layer we currently have defined with parameters) to allow us to specify penalty terms on the weight matrix and bias vector when creating an instance of the class and to add the corresponding penalty gradients to the returned value from the `grads_wrt_params` method.
#
# The penalty terms need to be specified as a class matching the interface of the `L1Penalty` and `L2Penalty` classes you implemented above, defining both a `__call__` method to calculate the penalty value for a parameter and a `grad` method to calculate the gradient of the penalty with respect to the parameter. Separate penalties can be specified for the weight and bias parameters, with it common to only regularise the weight parameters.
#
# The penalty terms for a layer are specifed using the `weights_penalty` and `biases_penalty` arguments to the `__init__` method of the `AffineLayer` class. If either (or both) ofthese are set to `None` (the default) no regularisation is applied to the corresponding parameter.
#
# Using the `L1Penalty` and `L2Penalty` classes you implemented in the previous exercise, train models to classify MNIST digit images with
#
#   * no regularisation
#   * an L1 penalty with coefficient $10^{-5}$ on the all of the weight matrix parameters
#   * an L1 penalty with coefficient $10^{-3}$ on the all of the weight matrix parameters
#   * an L2 penalty with coefficient $10^{-4}$ on the all of the weight matrix parameters
#   * an L2 penalty with coefficient $10^{-2}$ on the all of the weight matrix parameters
#
# The models should all have three affine layers interspersed with rectified linear layers (as implemented in the first exercise) and intermediate layers between the input and output should have dimensionalities of 100. The final output layer should be an `AffineLayer` (the model outputting the logarithms of the non-normalised class probabilties) and you should use the `CrossEntropySoftmaxError` as the error function (which calculates the softmax of the model outputs to convert to normalised class probabilities before calculating the corresponding multi-class cross entropy error).
#
# Use the `GlorotInit` class introduced in the first coursework to initialise the weights in all layers, using a gain of 0.5 (this adjusts for the fact that the rectified linear sets zeros all negative inputs), and initialises the biases to zero with a `ConstantInit` object.
#
# As an example the necessary parameter initialisers, model and error can be defined using
#
# ```python
# weights_init = GlorotUniformInit(0.5, rng)
# biases_init = ConstantInit(0.)
# input_dim, output_dim, hidden_dim = 784, 10, 100
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty),
#     ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty),
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty)
# ])
# error = CrossEntropySoftmaxError()
# ```
#
# This assumes all the relevant classes have been imported from their modules, a penalty object has been assigned to `weights_penalty` and a seeded random number generator assigned to `rng`.
#
# For each regularisation scheme, train the model for 100 epochs with a batch size of 50 and using a gradient descent with momentum learning rule with learning rate 0.01 and momentum coefficient 0.9. For each regularisation scheme you should store the run statistics (output of `Optimiser.train`) and the final values of the first layer weights for each of the trained models.

# %%
import logging
from mlp.data_providers import MNISTDataProvider

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 50
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %%
import math
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, UniformInit
from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule
from mlp.optimisers import Optimiser

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
ac_final_errors_train = []
ac_final_errors_valid = []
ac_final_accs_train = []
ac_final_accs_valid = []
ac_final_run_times = []

regu_data = []

# %%
#setup hyperparameters
learning_rate = 0.01
momentum_coef = 0.9
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate, mom_coeff=momentum_coef)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval)

regu_data.append([stats, keys, run_time, fig_1, ax_1, fig_2, ax_2])

print('    final error(train) = {0:.2e}'.format(stats[-1, keys['error(train)']]))
print('    final error(valid) = {0:.2e}'.format(stats[-1, keys['error(valid)']]))
print('    final acc(train)   = {0:.2e}'.format(stats[-1, keys['acc(train)']]))
print('    final acc(valid)   = {0:.2e}'.format(stats[-1, keys['acc(valid)']]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

fig_1.savefig('SigmoidFig1.pdf')
fig_2.savefig('SigmoidFig2.pdf')

ac_final_errors_train.append(stats[-1, keys['error(train)']])
ac_final_errors_valid.append(stats[-1, keys['error(valid)']])
ac_final_accs_train.append(stats[-1, keys['acc(train)']])
ac_final_accs_valid.append(stats[-1, keys['acc(valid)']])
ac_final_run_times.append(run_time * 1. / num_epochs)
# Out:
# Epoch 1: 2.9s to complete
#     error(train)=1.84e-01, acc(train)=9.47e-01, error(valid)=1.80e-01, acc(valid)=9.50e-01
# Epoch 2: 2.9s to complete
#     error(train)=1.25e-01, acc(train)=9.63e-01, error(valid)=1.41e-01, acc(valid)=9.58e-01
# Epoch 3: 2.9s to complete
#     error(train)=9.21e-02, acc(train)=9.73e-01, error(valid)=1.09e-01, acc(valid)=9.68e-01
# Epoch 4: 2.9s to complete
#     error(train)=7.61e-02, acc(train)=9.77e-01, error(valid)=1.09e-01, acc(valid)=9.70e-01
# Epoch 5: 3.0s to complete
#     error(train)=5.85e-02, acc(train)=9.82e-01, error(valid)=9.28e-02, acc(valid)=9.71e-01
# Epoch 6: 2.9s to complete
#     error(train)=4.30e-02, acc(train)=9.87e-01, error(valid)=8.45e-02, acc(valid)=9.75e-01
# Epoch 7: 3.0s to complete
#     error(train)=3.30e-02, acc(train)=9.91e-01, error(valid)=7.90e-02, acc(valid)=9.78e-01
# Epoch 8: 3.0s to complete
#     error(train)=3.32e-02, acc(train)=9.90e-01, error(valid)=8.57e-02, acc(valid)=9.76e-01
# Epoch 9: 3.0s to complete
#     error(train)=3.31e-02, acc(train)=9.90e-01, error(valid)=8.65e-02, acc(valid)=9.74e-01
# Epoch 10: 3.2s to complete
#     error(train)=2.43e-02, acc(train)=9.93e-01, error(valid)=8.33e-02, acc(valid)=9.78e-01
# Epoch 11: 3.1s to complete
#     error(train)=1.74e-02, acc(train)=9.96e-01, error(valid)=8.47e-02, acc(valid)=9.78e-01
# Epoch 12: 3.1s to complete
#     error(train)=1.73e-02, acc(train)=9.95e-01, error(valid)=8.88e-02, acc(valid)=9.78e-01
# Epoch 13: 3.0s to complete
#     error(train)=1.22e-02, acc(train)=9.97e-01, error(valid)=8.41e-02, acc(valid)=9.78e-01
# Epoch 14: 3.0s to complete
#     error(train)=1.04e-02, acc(train)=9.98e-01, error(valid)=8.87e-02, acc(valid)=9.78e-01
# Epoch 15: 3.0s to complete
#     error(train)=9.90e-03, acc(train)=9.98e-01, error(valid)=8.99e-02, acc(valid)=9.77e-01
# Epoch 16: 3.0s to complete
#     error(train)=5.12e-03, acc(train)=9.99e-01, error(valid)=8.44e-02, acc(valid)=9.80e-01
# Epoch 17: 3.0s to complete
#     error(train)=5.11e-03, acc(train)=9.99e-01, error(valid)=8.64e-02, acc(valid)=9.80e-01
# Epoch 18: 3.0s to complete
#     error(train)=4.10e-03, acc(train)=1.00e+00, error(valid)=8.95e-02, acc(valid)=9.80e-01
# Epoch 19: 3.0s to complete
#     error(train)=3.40e-03, acc(train)=1.00e+00, error(valid)=8.85e-02, acc(valid)=9.81e-01
# Epoch 20: 3.0s to complete
#     error(train)=2.38e-03, acc(train)=1.00e+00, error(valid)=8.98e-02, acc(valid)=9.80e-01
# Epoch 21: 3.1s to complete
#     error(train)=2.11e-03, acc(train)=1.00e+00, error(valid)=9.04e-02, acc(valid)=9.80e-01
# Epoch 22: 3.0s to complete
#     error(train)=1.72e-03, acc(train)=1.00e+00, error(valid)=8.96e-02, acc(valid)=9.80e-01
# Epoch 23: 3.4s to complete
#     error(train)=1.82e-03, acc(train)=1.00e+00, error(valid)=9.03e-02, acc(valid)=9.80e-01
# Epoch 24: 3.9s to complete
#     error(train)=1.59e-03, acc(train)=1.00e+00, error(valid)=9.42e-02, acc(valid)=9.81e-01
# Epoch 25: 3.3s to complete
#     error(train)=1.26e-03, acc(train)=1.00e+00, error(valid)=9.16e-02, acc(valid)=9.81e-01
# Epoch 26: 3.2s to complete
#     error(train)=1.27e-03, acc(train)=1.00e+00, error(valid)=9.41e-02, acc(valid)=9.81e-01
# Epoch 27: 3.0s to complete
#     error(train)=1.09e-03, acc(train)=1.00e+00, error(valid)=9.54e-02, acc(valid)=9.80e-01
# Epoch 28: 3.3s to complete
#     error(train)=9.57e-04, acc(train)=1.00e+00, error(valid)=9.49e-02, acc(valid)=9.81e-01
# Epoch 29: 3.7s to complete
#     error(train)=8.97e-04, acc(train)=1.00e+00, error(valid)=9.62e-02, acc(valid)=9.81e-01
# Epoch 30: 3.5s to complete
#     error(train)=8.58e-04, acc(train)=1.00e+00, error(valid)=9.54e-02, acc(valid)=9.81e-01
# Epoch 31: 3.5s to complete
#     error(train)=7.91e-04, acc(train)=1.00e+00, error(valid)=9.63e-02, acc(valid)=9.81e-01
# Epoch 32: 4.0s to complete
#     error(train)=8.02e-04, acc(train)=1.00e+00, error(valid)=9.80e-02, acc(valid)=9.80e-01
# Epoch 33: 3.7s to complete
#     error(train)=7.35e-04, acc(train)=1.00e+00, error(valid)=9.73e-02, acc(valid)=9.81e-01
# Epoch 34: 3.3s to complete
#     error(train)=6.74e-04, acc(train)=1.00e+00, error(valid)=9.83e-02, acc(valid)=9.81e-01
# Epoch 35: 3.0s to complete
#     error(train)=6.54e-04, acc(train)=1.00e+00, error(valid)=9.87e-02, acc(valid)=9.81e-01
# Epoch 36: 3.0s to complete
#     error(train)=6.14e-04, acc(train)=1.00e+00, error(valid)=9.92e-02, acc(valid)=9.81e-01
# Epoch 37: 3.6s to complete
#     error(train)=6.02e-04, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.81e-01
# Epoch 38: 3.0s to complete
#     error(train)=5.65e-04, acc(train)=1.00e+00, error(valid)=9.99e-02, acc(valid)=9.81e-01
# Epoch 39: 3.0s to complete
#     error(train)=5.39e-04, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.81e-01
# Epoch 40: 3.0s to complete
#     error(train)=5.18e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.81e-01
# Epoch 41: 3.0s to complete
#     error(train)=4.99e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01
# Epoch 42: 3.1s to complete
#     error(train)=4.96e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01
# Epoch 43: 3.0s to complete
#     error(train)=4.65e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01
# Epoch 44: 3.0s to complete
#     error(train)=4.48e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01
# Epoch 45: 3.0s to complete
#     error(train)=4.36e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01
# Epoch 46: 3.0s to complete
#     error(train)=4.23e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01
# Epoch 47: 3.0s to complete
#     error(train)=4.07e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01
# Epoch 48: 3.0s to complete
#     error(train)=3.93e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01
# Epoch 49: 3.1s to complete
#     error(train)=3.83e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01
# Epoch 50: 3.0s to complete
#     error(train)=3.72e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01
# Epoch 51: 3.0s to complete
#     error(train)=3.63e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01
# Epoch 52: 3.0s to complete
#     error(train)=3.56e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01
# Epoch 53: 3.0s to complete
#     error(train)=3.41e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01
# Epoch 54: 3.0s to complete
#     error(train)=3.32e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01
# Epoch 55: 3.1s to complete
#     error(train)=3.25e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01
# Epoch 56: 3.1s to complete
#     error(train)=3.16e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01
# Epoch 57: 3.0s to complete
#     error(train)=3.09e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01
# Epoch 58: 3.0s to complete
#     error(train)=3.06e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01
# Epoch 59: 3.0s to complete
#     error(train)=2.93e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01
# Epoch 60: 3.0s to complete
#     error(train)=2.86e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01
# Epoch 61: 3.0s to complete
#     error(train)=2.79e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01
# Epoch 62: 3.1s to complete
#     error(train)=2.76e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01
# Epoch 63: 3.1s to complete
#     error(train)=2.68e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01
# Epoch 64: 3.0s to complete
#     error(train)=2.63e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01
# Epoch 65: 3.0s to complete
#     error(train)=2.58e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01
# Epoch 66: 3.0s to complete
#     error(train)=2.55e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01
# Epoch 67: 3.0s to complete
#     error(train)=2.45e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.80e-01
# Epoch 68: 3.0s to complete
#     error(train)=2.40e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01
# Epoch 69: 3.0s to complete
#     error(train)=2.35e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01
# Epoch 70: 3.1s to complete
#     error(train)=2.32e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.80e-01
# Epoch 71: 3.0s to complete
#     error(train)=2.26e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01
# Epoch 72: 3.0s to complete
#     error(train)=2.23e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.80e-01
# Epoch 73: 3.0s to complete
#     error(train)=2.18e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01
# Epoch 74: 3.0s to complete
#     error(train)=2.15e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01
# Epoch 75: 3.0s to complete
#     error(train)=2.10e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01
# Epoch 76: 3.0s to complete
#     error(train)=2.08e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01
# Epoch 77: 3.0s to complete
#     error(train)=2.03e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01
# Epoch 78: 3.0s to complete
#     error(train)=2.00e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01
# Epoch 79: 3.0s to complete
#     error(train)=1.96e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01
# Epoch 80: 3.7s to complete
#     error(train)=1.92e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01
# Epoch 81: 3.0s to complete
#     error(train)=1.88e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01
# Epoch 82: 3.0s to complete
#     error(train)=1.87e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01
# Epoch 83: 3.0s to complete
#     error(train)=1.82e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01
# Epoch 84: 3.1s to complete
#     error(train)=1.80e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01
# Epoch 85: 3.0s to complete
#     error(train)=1.78e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01
# Epoch 86: 3.0s to complete
#     error(train)=1.76e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01
# Epoch 87: 3.1s to complete
#     error(train)=1.72e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 88: 3.0s to complete
#     error(train)=1.70e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 89: 3.0s to complete
#     error(train)=1.67e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 90: 3.0s to complete
#     error(train)=1.64e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 91: 3.1s to complete
#     error(train)=1.62e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 92: 3.4s to complete
#     error(train)=1.60e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 93: 3.3s to complete
#     error(train)=1.57e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01
# Epoch 94: 3.4s to complete
#     error(train)=1.55e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01
# Epoch 95: 3.2s to complete
#     error(train)=1.54e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01
# Epoch 96: 3.0s to complete
#     error(train)=1.51e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01
# Epoch 97: 3.3s to complete
#     error(train)=1.50e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01
# Epoch 98: 3.1s to complete
#     error(train)=1.47e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01
# Epoch 99: 3.0s to complete
#     error(train)=1.45e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01
# Epoch 100: 3.0s to complete
#     error(train)=1.43e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01
#     final error(train) = 1.43e-04
#     final error(valid) = 1.16e-01
#     final acc(train)   = 1.00e+00
#     final acc(valid)   = 9.81e-01
#     run time per epoch = 4.38

# %%
#setup hyperparameters

weights_penalty=L1Penalty(0.00001)

learning_rate = 0.01
momentum_coef = 0.9
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init,weights_penalty=weights_penalty)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate, mom_coeff=momentum_coef)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval)

regu_data.append([stats, keys, run_time, fig_1, ax_1, fig_2, ax_2])

print('    final error(train) = {0:.2e}'.format(stats[-1, keys['error(train)']]))
print('    final error(valid) = {0:.2e}'.format(stats[-1, keys['error(valid)']]))
print('    final acc(train)   = {0:.2e}'.format(stats[-1, keys['acc(train)']]))
print('    final acc(valid)   = {0:.2e}'.format(stats[-1, keys['acc(valid)']]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

fig_1.savefig('SigmoidFig1.pdf')
fig_2.savefig('SigmoidFig2.pdf')

ac_final_errors_train.append(stats[-1, keys['error(train)']])
ac_final_errors_valid.append(stats[-1, keys['error(valid)']])
ac_final_accs_train.append(stats[-1, keys['acc(train)']])
ac_final_accs_valid.append(stats[-1, keys['acc(valid)']])
ac_final_run_times.append(run_time * 1. / num_epochs)
# Out:
# Epoch 1: 4.7s to complete
#     error(train)=1.93e-01, acc(train)=9.43e-01, error(valid)=1.91e-01, acc(valid)=9.46e-01
# Epoch 2: 4.6s to complete
#     error(train)=1.25e-01, acc(train)=9.63e-01, error(valid)=1.34e-01, acc(valid)=9.60e-01
# Epoch 3: 4.6s to complete
#     error(train)=9.11e-02, acc(train)=9.74e-01, error(valid)=1.11e-01, acc(valid)=9.67e-01
# Epoch 4: 4.5s to complete
#     error(train)=7.00e-02, acc(train)=9.79e-01, error(valid)=9.62e-02, acc(valid)=9.71e-01
# Epoch 5: 4.3s to complete
#     error(train)=5.53e-02, acc(train)=9.84e-01, error(valid)=9.52e-02, acc(valid)=9.72e-01
# Epoch 6: 4.4s to complete
#     error(train)=4.51e-02, acc(train)=9.88e-01, error(valid)=8.94e-02, acc(valid)=9.73e-01
# Epoch 7: 4.4s to complete
#     error(train)=4.37e-02, acc(train)=9.88e-01, error(valid)=8.89e-02, acc(valid)=9.73e-01
# Epoch 8: 4.5s to complete
#     error(train)=3.73e-02, acc(train)=9.90e-01, error(valid)=8.77e-02, acc(valid)=9.75e-01
# Epoch 9: 4.3s to complete
#     error(train)=3.06e-02, acc(train)=9.91e-01, error(valid)=8.64e-02, acc(valid)=9.75e-01
# Epoch 10: 4.5s to complete
#     error(train)=2.55e-02, acc(train)=9.93e-01, error(valid)=8.45e-02, acc(valid)=9.76e-01
# Epoch 11: 4.3s to complete
#     error(train)=1.92e-02, acc(train)=9.95e-01, error(valid)=8.46e-02, acc(valid)=9.77e-01
# Epoch 12: 4.3s to complete
#     error(train)=1.55e-02, acc(train)=9.97e-01, error(valid)=8.18e-02, acc(valid)=9.78e-01
# Epoch 13: 4.3s to complete
#     error(train)=1.60e-02, acc(train)=9.96e-01, error(valid)=8.33e-02, acc(valid)=9.78e-01
# Epoch 14: 4.3s to complete
#     error(train)=1.32e-02, acc(train)=9.97e-01, error(valid)=8.63e-02, acc(valid)=9.78e-01
# Epoch 15: 4.6s to complete
#     error(train)=9.95e-03, acc(train)=9.98e-01, error(valid)=8.10e-02, acc(valid)=9.78e-01
# Epoch 16: 4.4s to complete
#     error(train)=1.03e-02, acc(train)=9.98e-01, error(valid)=7.95e-02, acc(valid)=9.79e-01
# Epoch 17: 4.5s to complete
#     error(train)=8.10e-03, acc(train)=9.99e-01, error(valid)=8.38e-02, acc(valid)=9.78e-01
# Epoch 18: 4.4s to complete
#     error(train)=5.74e-03, acc(train)=9.99e-01, error(valid)=7.72e-02, acc(valid)=9.81e-01
# Epoch 19: 4.3s to complete
#     error(train)=4.72e-03, acc(train)=1.00e+00, error(valid)=7.90e-02, acc(valid)=9.81e-01
# Epoch 20: 4.3s to complete
#     error(train)=6.60e-03, acc(train)=9.99e-01, error(valid)=8.99e-02, acc(valid)=9.78e-01
# Epoch 21: 4.3s to complete
#     error(train)=3.76e-03, acc(train)=1.00e+00, error(valid)=7.86e-02, acc(valid)=9.81e-01
# Epoch 22: 4.5s to complete
#     error(train)=3.28e-03, acc(train)=1.00e+00, error(valid)=8.10e-02, acc(valid)=9.81e-01
# Epoch 23: 4.3s to complete
#     error(train)=2.85e-03, acc(train)=1.00e+00, error(valid)=8.08e-02, acc(valid)=9.80e-01
# Epoch 24: 4.8s to complete
#     error(train)=4.08e-03, acc(train)=1.00e+00, error(valid)=8.49e-02, acc(valid)=9.79e-01
# Epoch 25: 4.8s to complete
#     error(train)=2.78e-03, acc(train)=1.00e+00, error(valid)=7.88e-02, acc(valid)=9.81e-01
# Epoch 26: 4.8s to complete
#     error(train)=2.40e-03, acc(train)=1.00e+00, error(valid)=7.87e-02, acc(valid)=9.81e-01
# Epoch 27: 4.4s to complete
#     error(train)=2.40e-03, acc(train)=1.00e+00, error(valid)=8.20e-02, acc(valid)=9.80e-01
# Epoch 28: 4.8s to complete
#     error(train)=2.19e-03, acc(train)=1.00e+00, error(valid)=8.01e-02, acc(valid)=9.81e-01
# Epoch 29: 4.9s to complete
#     error(train)=2.10e-03, acc(train)=1.00e+00, error(valid)=7.95e-02, acc(valid)=9.81e-01
# Epoch 30: 4.9s to complete
#     error(train)=1.94e-03, acc(train)=1.00e+00, error(valid)=8.15e-02, acc(valid)=9.81e-01
# Epoch 31: 5.7s to complete
#     error(train)=2.15e-03, acc(train)=1.00e+00, error(valid)=8.20e-02, acc(valid)=9.81e-01
# Epoch 32: 4.5s to complete
#     error(train)=1.89e-03, acc(train)=1.00e+00, error(valid)=7.92e-02, acc(valid)=9.81e-01
# Epoch 33: 4.3s to complete
#     error(train)=1.92e-03, acc(train)=1.00e+00, error(valid)=7.94e-02, acc(valid)=9.82e-01
# Epoch 34: 4.3s to complete
#     error(train)=2.13e-03, acc(train)=1.00e+00, error(valid)=7.90e-02, acc(valid)=9.80e-01
# Epoch 35: 4.3s to complete
#     error(train)=1.80e-03, acc(train)=1.00e+00, error(valid)=8.05e-02, acc(valid)=9.81e-01
# Epoch 36: 4.5s to complete
#     error(train)=2.12e-03, acc(train)=1.00e+00, error(valid)=8.10e-02, acc(valid)=9.81e-01
# Epoch 37: 4.3s to complete
#     error(train)=2.11e-03, acc(train)=1.00e+00, error(valid)=8.08e-02, acc(valid)=9.81e-01
# Epoch 38: 4.5s to complete
#     error(train)=1.75e-03, acc(train)=1.00e+00, error(valid)=7.97e-02, acc(valid)=9.81e-01
# Epoch 39: 4.3s to complete
#     error(train)=1.73e-03, acc(train)=1.00e+00, error(valid)=8.10e-02, acc(valid)=9.81e-01
# Epoch 40: 4.4s to complete
#     error(train)=1.77e-03, acc(train)=1.00e+00, error(valid)=8.16e-02, acc(valid)=9.81e-01
# Epoch 41: 4.3s to complete
#     error(train)=1.86e-03, acc(train)=1.00e+00, error(valid)=7.98e-02, acc(valid)=9.80e-01
# Epoch 42: 4.3s to complete
#     error(train)=1.77e-03, acc(train)=1.00e+00, error(valid)=8.07e-02, acc(valid)=9.82e-01
# Epoch 43: 4.7s to complete
#     error(train)=1.86e-03, acc(train)=1.00e+00, error(valid)=8.14e-02, acc(valid)=9.80e-01
# Epoch 44: 4.7s to complete
#     error(train)=1.70e-03, acc(train)=1.00e+00, error(valid)=7.95e-02, acc(valid)=9.81e-01
# Epoch 45: 4.6s to complete
#     error(train)=1.87e-03, acc(train)=1.00e+00, error(valid)=8.17e-02, acc(valid)=9.81e-01
# Epoch 46: 4.9s to complete
#     error(train)=1.97e-03, acc(train)=1.00e+00, error(valid)=7.96e-02, acc(valid)=9.80e-01
# Epoch 47: 4.4s to complete
#     error(train)=1.75e-03, acc(train)=1.00e+00, error(valid)=8.21e-02, acc(valid)=9.82e-01
# Epoch 48: 4.4s to complete
#     error(train)=1.65e-03, acc(train)=1.00e+00, error(valid)=8.02e-02, acc(valid)=9.81e-01
# Epoch 49: 4.5s to complete
#     error(train)=1.76e-03, acc(train)=1.00e+00, error(valid)=7.94e-02, acc(valid)=9.81e-01
# Epoch 50: 4.5s to complete
#     error(train)=1.68e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.81e-01
# Epoch 51: 4.4s to complete
#     error(train)=1.83e-03, acc(train)=1.00e+00, error(valid)=8.10e-02, acc(valid)=9.80e-01
# Epoch 52: 4.5s to complete
#     error(train)=1.67e-03, acc(train)=1.00e+00, error(valid)=8.04e-02, acc(valid)=9.82e-01
# Epoch 53: 4.3s to complete
#     error(train)=1.78e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.82e-01
# Epoch 54: 4.4s to complete
#     error(train)=1.64e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.81e-01
# Epoch 55: 4.3s to complete
#     error(train)=1.85e-03, acc(train)=1.00e+00, error(valid)=8.06e-02, acc(valid)=9.81e-01
# Epoch 56: 4.4s to complete
#     error(train)=1.80e-03, acc(train)=1.00e+00, error(valid)=8.18e-02, acc(valid)=9.81e-01
# Epoch 57: 4.5s to complete
#     error(train)=1.92e-03, acc(train)=1.00e+00, error(valid)=8.14e-02, acc(valid)=9.80e-01
# Epoch 58: 4.3s to complete
#     error(train)=1.81e-03, acc(train)=1.00e+00, error(valid)=7.95e-02, acc(valid)=9.81e-01
# Epoch 59: 4.5s to complete
#     error(train)=1.65e-03, acc(train)=1.00e+00, error(valid)=7.91e-02, acc(valid)=9.81e-01
# Epoch 60: 4.4s to complete
#     error(train)=1.66e-03, acc(train)=1.00e+00, error(valid)=7.83e-02, acc(valid)=9.82e-01
# Epoch 61: 4.3s to complete
#     error(train)=2.04e-03, acc(train)=1.00e+00, error(valid)=8.27e-02, acc(valid)=9.82e-01
# Epoch 62: 4.3s to complete
#     error(train)=1.79e-03, acc(train)=1.00e+00, error(valid)=8.07e-02, acc(valid)=9.80e-01
# Epoch 63: 4.3s to complete
#     error(train)=1.69e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.82e-01
# Epoch 64: 4.5s to complete
#     error(train)=1.67e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.82e-01
# Epoch 65: 4.3s to complete
#     error(train)=2.32e-03, acc(train)=1.00e+00, error(valid)=8.02e-02, acc(valid)=9.81e-01
# Epoch 66: 4.5s to complete
#     error(train)=2.04e-02, acc(train)=9.93e-01, error(valid)=1.09e-01, acc(valid)=9.75e-01
# Epoch 67: 4.3s to complete
#     error(train)=7.46e-02, acc(train)=9.78e-01, error(valid)=1.57e-01, acc(valid)=9.65e-01
# Epoch 68: 4.3s to complete
#     error(train)=1.44e-02, acc(train)=9.95e-01, error(valid)=1.02e-01, acc(valid)=9.78e-01
# Epoch 69: 4.4s to complete
#     error(train)=1.47e-02, acc(train)=9.95e-01, error(valid)=1.05e-01, acc(valid)=9.76e-01
# Epoch 70: 4.4s to complete
#     error(train)=1.14e-02, acc(train)=9.96e-01, error(valid)=1.09e-01, acc(valid)=9.76e-01
# Epoch 71: 5.4s to complete
#     error(train)=3.67e-03, acc(train)=1.00e+00, error(valid)=9.11e-02, acc(valid)=9.81e-01
# Epoch 72: 5.1s to complete
#     error(train)=1.59e-03, acc(train)=1.00e+00, error(valid)=8.29e-02, acc(valid)=9.81e-01
# Epoch 73: 5.8s to complete
#     error(train)=2.29e-03, acc(train)=1.00e+00, error(valid)=8.74e-02, acc(valid)=9.81e-01
# Epoch 74: 4.7s to complete
#     error(train)=9.84e-04, acc(train)=1.00e+00, error(valid)=8.17e-02, acc(valid)=9.82e-01
# Epoch 75: 4.3s to complete
#     error(train)=1.01e-03, acc(train)=1.00e+00, error(valid)=8.03e-02, acc(valid)=9.82e-01
# Epoch 76: 4.4s to complete
#     error(train)=1.02e-03, acc(train)=1.00e+00, error(valid)=8.15e-02, acc(valid)=9.83e-01
# Epoch 77: 4.7s to complete
#     error(train)=9.71e-04, acc(train)=1.00e+00, error(valid)=8.10e-02, acc(valid)=9.82e-01
# Epoch 78: 4.6s to complete
#     error(train)=1.02e-03, acc(train)=1.00e+00, error(valid)=8.10e-02, acc(valid)=9.83e-01
# Epoch 79: 4.4s to complete
#     error(train)=1.09e-03, acc(train)=1.00e+00, error(valid)=8.11e-02, acc(valid)=9.82e-01
# Epoch 80: 4.6s to complete
#     error(train)=1.10e-03, acc(train)=1.00e+00, error(valid)=8.05e-02, acc(valid)=9.82e-01
# Epoch 81: 4.9s to complete
#     error(train)=1.07e-03, acc(train)=1.00e+00, error(valid)=8.02e-02, acc(valid)=9.82e-01
# Epoch 82: 5.0s to complete
#     error(train)=1.12e-03, acc(train)=1.00e+00, error(valid)=7.92e-02, acc(valid)=9.83e-01
# Epoch 83: 4.8s to complete
#     error(train)=1.11e-03, acc(train)=1.00e+00, error(valid)=8.03e-02, acc(valid)=9.82e-01
# Epoch 84: 5.1s to complete
#     error(train)=1.14e-03, acc(train)=1.00e+00, error(valid)=7.92e-02, acc(valid)=9.82e-01
# Epoch 85: 5.5s to complete
#     error(train)=1.20e-03, acc(train)=1.00e+00, error(valid)=7.89e-02, acc(valid)=9.82e-01
# Epoch 86: 5.1s to complete
#     error(train)=1.23e-03, acc(train)=1.00e+00, error(valid)=7.90e-02, acc(valid)=9.82e-01
# Epoch 87: 4.3s to complete
#     error(train)=1.22e-03, acc(train)=1.00e+00, error(valid)=7.98e-02, acc(valid)=9.82e-01
# Epoch 88: 4.9s to complete
#     error(train)=1.23e-03, acc(train)=1.00e+00, error(valid)=7.80e-02, acc(valid)=9.83e-01
# Epoch 89: 4.3s to complete
#     error(train)=1.32e-03, acc(train)=1.00e+00, error(valid)=7.83e-02, acc(valid)=9.82e-01
# Epoch 90: 4.3s to complete
#     error(train)=1.27e-03, acc(train)=1.00e+00, error(valid)=7.77e-02, acc(valid)=9.82e-01
# Epoch 91: 4.3s to complete
#     error(train)=1.28e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.82e-01
# Epoch 92: 4.4s to complete
#     error(train)=1.33e-03, acc(train)=1.00e+00, error(valid)=7.90e-02, acc(valid)=9.83e-01
# Epoch 93: 4.3s to complete
#     error(train)=1.32e-03, acc(train)=1.00e+00, error(valid)=7.71e-02, acc(valid)=9.82e-01
# Epoch 94: 4.4s to complete
#     error(train)=1.36e-03, acc(train)=1.00e+00, error(valid)=7.83e-02, acc(valid)=9.82e-01
# Epoch 95: 4.3s to complete
#     error(train)=1.39e-03, acc(train)=1.00e+00, error(valid)=7.77e-02, acc(valid)=9.82e-01
# Epoch 96: 4.6s to complete
#     error(train)=1.62e-03, acc(train)=1.00e+00, error(valid)=8.14e-02, acc(valid)=9.82e-01
# Epoch 97: 4.3s to complete
#     error(train)=1.45e-03, acc(train)=1.00e+00, error(valid)=7.81e-02, acc(valid)=9.82e-01
# Epoch 98: 4.3s to complete
#     error(train)=1.46e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.81e-01
# Epoch 99: 4.4s to complete
#     error(train)=1.54e-03, acc(train)=1.00e+00, error(valid)=7.85e-02, acc(valid)=9.82e-01
# Epoch 100: 4.4s to complete
#     error(train)=1.37e-03, acc(train)=1.00e+00, error(valid)=7.69e-02, acc(valid)=9.82e-01
#     final error(train) = 1.37e-03
#     final error(valid) = 7.69e-02
#     final acc(train)   = 1.00e+00
#     final acc(valid)   = 9.82e-01
#     run time per epoch = 5.86

# %%
#setup hyperparameters

weights_penalty=L1Penalty(0.001)

learning_rate = 0.01
momentum_coef = 0.9
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init,weights_penalty=weights_penalty)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate, mom_coeff=momentum_coef)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval)

regu_data.append([stats, keys, run_time, fig_1, ax_1, fig_2, ax_2])

print('    final error(train) = {0:.2e}'.format(stats[-1, keys['error(train)']]))
print('    final error(valid) = {0:.2e}'.format(stats[-1, keys['error(valid)']]))
print('    final acc(train)   = {0:.2e}'.format(stats[-1, keys['acc(train)']]))
print('    final acc(valid)   = {0:.2e}'.format(stats[-1, keys['acc(valid)']]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

fig_1.savefig('SigmoidFig1.pdf')
fig_2.savefig('SigmoidFig2.pdf')

ac_final_errors_train.append(stats[-1, keys['error(train)']])
ac_final_errors_valid.append(stats[-1, keys['error(valid)']])
ac_final_accs_train.append(stats[-1, keys['acc(train)']])
ac_final_accs_valid.append(stats[-1, keys['acc(valid)']])
ac_final_run_times.append(run_time * 1. / num_epochs)
# Out:
# Epoch 1: 4.4s to complete
#     error(train)=3.37e-01, acc(train)=9.09e-01, error(valid)=3.13e-01, acc(valid)=9.16e-01
# Epoch 2: 4.3s to complete
#     error(train)=2.98e-01, acc(train)=9.18e-01, error(valid)=2.76e-01, acc(valid)=9.23e-01
# Epoch 3: 4.3s to complete
#     error(train)=2.49e-01, acc(train)=9.31e-01, error(valid)=2.31e-01, acc(valid)=9.36e-01
# Epoch 4: 4.3s to complete
#     error(train)=2.48e-01, acc(train)=9.28e-01, error(valid)=2.35e-01, acc(valid)=9.33e-01
# Epoch 5: 4.3s to complete
#     error(train)=2.30e-01, acc(train)=9.35e-01, error(valid)=2.23e-01, acc(valid)=9.36e-01
# Epoch 6: 4.3s to complete
#     error(train)=2.45e-01, acc(train)=9.32e-01, error(valid)=2.31e-01, acc(valid)=9.35e-01
# Epoch 7: 4.4s to complete
#     error(train)=2.25e-01, acc(train)=9.33e-01, error(valid)=2.20e-01, acc(valid)=9.34e-01
# Epoch 8: 4.3s to complete
#     error(train)=2.05e-01, acc(train)=9.44e-01, error(valid)=2.03e-01, acc(valid)=9.43e-01
# Epoch 9: 4.3s to complete
#     error(train)=2.35e-01, acc(train)=9.31e-01, error(valid)=2.25e-01, acc(valid)=9.35e-01
# Epoch 10: 4.4s to complete
#     error(train)=2.47e-01, acc(train)=9.27e-01, error(valid)=2.38e-01, acc(valid)=9.29e-01
# Epoch 11: 4.5s to complete
#     error(train)=1.95e-01, acc(train)=9.43e-01, error(valid)=1.94e-01, acc(valid)=9.43e-01
# Epoch 12: 4.3s to complete
#     error(train)=1.90e-01, acc(train)=9.45e-01, error(valid)=1.91e-01, acc(valid)=9.43e-01
# Epoch 13: 4.5s to complete
#     error(train)=1.97e-01, acc(train)=9.42e-01, error(valid)=1.94e-01, acc(valid)=9.46e-01
# Epoch 14: 4.3s to complete
#     error(train)=2.21e-01, acc(train)=9.34e-01, error(valid)=2.16e-01, acc(valid)=9.37e-01
# Epoch 15: 4.5s to complete
#     error(train)=1.95e-01, acc(train)=9.42e-01, error(valid)=1.92e-01, acc(valid)=9.46e-01
# Epoch 16: 4.4s to complete
#     error(train)=2.00e-01, acc(train)=9.41e-01, error(valid)=1.94e-01, acc(valid)=9.46e-01
# Epoch 17: 4.3s to complete
#     error(train)=1.93e-01, acc(train)=9.44e-01, error(valid)=1.86e-01, acc(valid)=9.48e-01
# Epoch 18: 4.3s to complete
#     error(train)=1.94e-01, acc(train)=9.43e-01, error(valid)=1.91e-01, acc(valid)=9.45e-01
# Epoch 19: 4.4s to complete
#     error(train)=2.18e-01, acc(train)=9.35e-01, error(valid)=2.20e-01, acc(valid)=9.35e-01
# Epoch 20: 4.3s to complete
#     error(train)=1.97e-01, acc(train)=9.43e-01, error(valid)=1.97e-01, acc(valid)=9.42e-01
# Epoch 21: 4.4s to complete
#     error(train)=1.98e-01, acc(train)=9.42e-01, error(valid)=2.00e-01, acc(valid)=9.42e-01
# Epoch 22: 4.4s to complete
#     error(train)=2.02e-01, acc(train)=9.40e-01, error(valid)=1.99e-01, acc(valid)=9.42e-01
# Epoch 23: 4.5s to complete
#     error(train)=2.15e-01, acc(train)=9.34e-01, error(valid)=2.13e-01, acc(valid)=9.35e-01
# Epoch 24: 4.3s to complete
#     error(train)=1.95e-01, acc(train)=9.42e-01, error(valid)=1.94e-01, acc(valid)=9.43e-01
# Epoch 25: 4.3s to complete
#     error(train)=1.83e-01, acc(train)=9.46e-01, error(valid)=1.81e-01, acc(valid)=9.47e-01
# Epoch 26: 4.4s to complete
#     error(train)=2.04e-01, acc(train)=9.39e-01, error(valid)=2.03e-01, acc(valid)=9.40e-01
# Epoch 27: 4.3s to complete
#     error(train)=2.07e-01, acc(train)=9.37e-01, error(valid)=2.06e-01, acc(valid)=9.39e-01
# Epoch 28: 4.6s to complete
#     error(train)=2.43e-01, acc(train)=9.29e-01, error(valid)=2.37e-01, acc(valid)=9.31e-01
# Epoch 29: 4.4s to complete
#     error(train)=1.90e-01, acc(train)=9.45e-01, error(valid)=1.90e-01, acc(valid)=9.44e-01
# Epoch 30: 4.4s to complete
#     error(train)=1.92e-01, acc(train)=9.43e-01, error(valid)=1.87e-01, acc(valid)=9.47e-01
# Epoch 31: 4.4s to complete
#     error(train)=1.87e-01, acc(train)=9.45e-01, error(valid)=1.86e-01, acc(valid)=9.45e-01
# Epoch 32: 4.4s to complete
#     error(train)=1.88e-01, acc(train)=9.44e-01, error(valid)=1.86e-01, acc(valid)=9.44e-01
# Epoch 33: 4.5s to complete
#     error(train)=1.99e-01, acc(train)=9.43e-01, error(valid)=1.98e-01, acc(valid)=9.42e-01
# Epoch 34: 4.4s to complete
#     error(train)=1.90e-01, acc(train)=9.43e-01, error(valid)=1.85e-01, acc(valid)=9.44e-01
# Epoch 35: 4.5s to complete
#     error(train)=1.92e-01, acc(train)=9.44e-01, error(valid)=1.92e-01, acc(valid)=9.44e-01
# Epoch 36: 4.4s to complete
#     error(train)=1.79e-01, acc(train)=9.49e-01, error(valid)=1.80e-01, acc(valid)=9.46e-01
# Epoch 37: 4.4s to complete
#     error(train)=1.94e-01, acc(train)=9.42e-01, error(valid)=1.99e-01, acc(valid)=9.39e-01
# Epoch 38: 4.4s to complete
#     error(train)=1.79e-01, acc(train)=9.48e-01, error(valid)=1.83e-01, acc(valid)=9.47e-01
# Epoch 39: 4.4s to complete
#     error(train)=1.78e-01, acc(train)=9.50e-01, error(valid)=1.80e-01, acc(valid)=9.48e-01
# Epoch 40: 4.4s to complete
#     error(train)=1.84e-01, acc(train)=9.46e-01, error(valid)=1.84e-01, acc(valid)=9.45e-01
# Epoch 41: 4.4s to complete
#     error(train)=1.89e-01, acc(train)=9.45e-01, error(valid)=1.88e-01, acc(valid)=9.46e-01
# Epoch 42: 4.4s to complete
#     error(train)=1.74e-01, acc(train)=9.48e-01, error(valid)=1.77e-01, acc(valid)=9.47e-01
# Epoch 43: 4.4s to complete
#     error(train)=1.89e-01, acc(train)=9.44e-01, error(valid)=1.85e-01, acc(valid)=9.45e-01
# Epoch 44: 4.4s to complete
#     error(train)=2.00e-01, acc(train)=9.37e-01, error(valid)=1.94e-01, acc(valid)=9.42e-01
# Epoch 45: 4.4s to complete
#     error(train)=1.78e-01, acc(train)=9.47e-01, error(valid)=1.83e-01, acc(valid)=9.44e-01
# Epoch 46: 4.3s to complete
#     error(train)=1.79e-01, acc(train)=9.47e-01, error(valid)=1.87e-01, acc(valid)=9.43e-01
# Epoch 47: 4.3s to complete
#     error(train)=1.75e-01, acc(train)=9.49e-01, error(valid)=1.74e-01, acc(valid)=9.50e-01
# Epoch 48: 4.4s to complete
#     error(train)=2.12e-01, acc(train)=9.34e-01, error(valid)=2.11e-01, acc(valid)=9.37e-01
# Epoch 49: 4.3s to complete
#     error(train)=1.91e-01, acc(train)=9.44e-01, error(valid)=1.89e-01, acc(valid)=9.45e-01
# Epoch 50: 4.3s to complete
#     error(train)=2.23e-01, acc(train)=9.31e-01, error(valid)=2.16e-01, acc(valid)=9.36e-01
# Epoch 51: 4.5s to complete
#     error(train)=1.78e-01, acc(train)=9.50e-01, error(valid)=1.76e-01, acc(valid)=9.47e-01
# Epoch 52: 4.3s to complete
#     error(train)=1.83e-01, acc(train)=9.46e-01, error(valid)=1.87e-01, acc(valid)=9.45e-01
# Epoch 53: 4.3s to complete
#     error(train)=1.63e-01, acc(train)=9.53e-01, error(valid)=1.65e-01, acc(valid)=9.52e-01
# Epoch 54: 4.3s to complete
#     error(train)=2.03e-01, acc(train)=9.38e-01, error(valid)=2.07e-01, acc(valid)=9.39e-01
# Epoch 55: 4.4s to complete
#     error(train)=1.72e-01, acc(train)=9.50e-01, error(valid)=1.74e-01, acc(valid)=9.50e-01
# Epoch 56: 4.5s to complete
#     error(train)=1.81e-01, acc(train)=9.46e-01, error(valid)=1.79e-01, acc(valid)=9.47e-01
# Epoch 57: 4.3s to complete
#     error(train)=2.02e-01, acc(train)=9.38e-01, error(valid)=1.94e-01, acc(valid)=9.42e-01
# Epoch 58: 4.3s to complete
#     error(train)=1.80e-01, acc(train)=9.47e-01, error(valid)=1.79e-01, acc(valid)=9.46e-01
# Epoch 59: 4.4s to complete
#     error(train)=1.88e-01, acc(train)=9.46e-01, error(valid)=1.89e-01, acc(valid)=9.47e-01
# Epoch 60: 4.3s to complete
#     error(train)=1.73e-01, acc(train)=9.49e-01, error(valid)=1.70e-01, acc(valid)=9.49e-01
# Epoch 61: 4.3s to complete
#     error(train)=1.89e-01, acc(train)=9.43e-01, error(valid)=1.90e-01, acc(valid)=9.41e-01
# Epoch 62: 4.4s to complete
#     error(train)=1.79e-01, acc(train)=9.46e-01, error(valid)=1.81e-01, acc(valid)=9.46e-01
# Epoch 63: 4.3s to complete
#     error(train)=2.07e-01, acc(train)=9.41e-01, error(valid)=2.02e-01, acc(valid)=9.43e-01
# Epoch 64: 4.3s to complete
#     error(train)=1.86e-01, acc(train)=9.45e-01, error(valid)=1.83e-01, acc(valid)=9.47e-01
# Epoch 65: 4.3s to complete
#     error(train)=1.80e-01, acc(train)=9.47e-01, error(valid)=1.81e-01, acc(valid)=9.48e-01
# Epoch 66: 4.5s to complete
#     error(train)=1.72e-01, acc(train)=9.49e-01, error(valid)=1.74e-01, acc(valid)=9.50e-01
# Epoch 67: 4.3s to complete
#     error(train)=1.83e-01, acc(train)=9.44e-01, error(valid)=1.86e-01, acc(valid)=9.43e-01
# Epoch 68: 4.3s to complete
#     error(train)=1.85e-01, acc(train)=9.46e-01, error(valid)=1.82e-01, acc(valid)=9.47e-01
# Epoch 69: 4.3s to complete
#     error(train)=1.76e-01, acc(train)=9.47e-01, error(valid)=1.75e-01, acc(valid)=9.48e-01
# Epoch 70: 4.3s to complete
#     error(train)=1.88e-01, acc(train)=9.44e-01, error(valid)=1.93e-01, acc(valid)=9.41e-01
# Epoch 71: 4.3s to complete
#     error(train)=1.77e-01, acc(train)=9.47e-01, error(valid)=1.79e-01, acc(valid)=9.46e-01
# Epoch 72: 4.3s to complete
#     error(train)=1.69e-01, acc(train)=9.50e-01, error(valid)=1.70e-01, acc(valid)=9.50e-01
# Epoch 73: 4.3s to complete
#     error(train)=1.84e-01, acc(train)=9.46e-01, error(valid)=1.87e-01, acc(valid)=9.45e-01
# Epoch 74: 4.3s to complete
#     error(train)=2.00e-01, acc(train)=9.39e-01, error(valid)=1.98e-01, acc(valid)=9.41e-01
# Epoch 75: 4.3s to complete
#     error(train)=1.78e-01, acc(train)=9.48e-01, error(valid)=1.82e-01, acc(valid)=9.47e-01
# Epoch 76: 4.3s to complete
#     error(train)=1.86e-01, acc(train)=9.44e-01, error(valid)=1.88e-01, acc(valid)=9.44e-01
# Epoch 77: 4.3s to complete
#     error(train)=2.04e-01, acc(train)=9.38e-01, error(valid)=1.98e-01, acc(valid)=9.41e-01
# Epoch 78: 4.3s to complete
#     error(train)=1.63e-01, acc(train)=9.53e-01, error(valid)=1.64e-01, acc(valid)=9.54e-01
# Epoch 79: 4.3s to complete
#     error(train)=1.69e-01, acc(train)=9.50e-01, error(valid)=1.70e-01, acc(valid)=9.50e-01
# Epoch 80: 4.3s to complete
#     error(train)=1.80e-01, acc(train)=9.45e-01, error(valid)=1.81e-01, acc(valid)=9.44e-01
# Epoch 81: 4.3s to complete
#     error(train)=1.64e-01, acc(train)=9.51e-01, error(valid)=1.66e-01, acc(valid)=9.52e-01
# Epoch 82: 4.5s to complete
#     error(train)=1.96e-01, acc(train)=9.39e-01, error(valid)=1.95e-01, acc(valid)=9.42e-01
# Epoch 83: 4.3s to complete
#     error(train)=1.82e-01, acc(train)=9.45e-01, error(valid)=1.82e-01, acc(valid)=9.45e-01
# Epoch 84: 4.3s to complete
#     error(train)=1.90e-01, acc(train)=9.44e-01, error(valid)=1.89e-01, acc(valid)=9.45e-01
# Epoch 85: 4.3s to complete
#     error(train)=1.88e-01, acc(train)=9.42e-01, error(valid)=1.84e-01, acc(valid)=9.47e-01
# Epoch 86: 4.3s to complete
#     error(train)=1.93e-01, acc(train)=9.40e-01, error(valid)=1.94e-01, acc(valid)=9.42e-01
# Epoch 87: 4.3s to complete
#     error(train)=1.93e-01, acc(train)=9.42e-01, error(valid)=1.92e-01, acc(valid)=9.44e-01
# Epoch 88: 4.3s to complete
#     error(train)=1.85e-01, acc(train)=9.44e-01, error(valid)=1.83e-01, acc(valid)=9.45e-01
# Epoch 89: 4.3s to complete
#     error(train)=1.88e-01, acc(train)=9.44e-01, error(valid)=1.87e-01, acc(valid)=9.45e-01
# Epoch 90: 4.4s to complete
#     error(train)=1.79e-01, acc(train)=9.46e-01, error(valid)=1.79e-01, acc(valid)=9.49e-01
# Epoch 91: 4.3s to complete
#     error(train)=2.13e-01, acc(train)=9.37e-01, error(valid)=2.03e-01, acc(valid)=9.41e-01
# Epoch 92: 4.3s to complete
#     error(train)=2.12e-01, acc(train)=9.34e-01, error(valid)=2.08e-01, acc(valid)=9.37e-01
# Epoch 93: 4.3s to complete
#     error(train)=1.75e-01, acc(train)=9.48e-01, error(valid)=1.72e-01, acc(valid)=9.49e-01
# Epoch 94: 4.3s to complete
#     error(train)=1.81e-01, acc(train)=9.45e-01, error(valid)=1.86e-01, acc(valid)=9.42e-01
# Epoch 95: 4.3s to complete
#     error(train)=1.89e-01, acc(train)=9.42e-01, error(valid)=1.92e-01, acc(valid)=9.43e-01
# Epoch 96: 4.6s to complete
#     error(train)=1.79e-01, acc(train)=9.47e-01, error(valid)=1.78e-01, acc(valid)=9.49e-01
# Epoch 97: 4.7s to complete
#     error(train)=1.75e-01, acc(train)=9.49e-01, error(valid)=1.75e-01, acc(valid)=9.48e-01
# Epoch 98: 4.8s to complete
#     error(train)=1.66e-01, acc(train)=9.51e-01, error(valid)=1.66e-01, acc(valid)=9.52e-01
# Epoch 99: 4.8s to complete
#     error(train)=1.77e-01, acc(train)=9.46e-01, error(valid)=1.83e-01, acc(valid)=9.46e-01
# Epoch 100: 4.3s to complete
#     error(train)=1.85e-01, acc(train)=9.45e-01, error(valid)=1.83e-01, acc(valid)=9.48e-01
#     final error(train) = 1.85e-01
#     final error(valid) = 1.83e-01
#     final acc(train)   = 9.45e-01
#     final acc(valid)   = 9.48e-01
#     run time per epoch = 5.57

# %%
#setup hyperparameters

weights_penalty=L2Penalty(0.0001)

learning_rate = 0.01
momentum_coef = 0.9
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init,weights_penalty=weights_penalty)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate, mom_coeff=momentum_coef)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval)

regu_data.append([stats, keys, run_time, fig_1, ax_1, fig_2, ax_2])

print('    final error(train) = {0:.2e}'.format(stats[-1, keys['error(train)']]))
print('    final error(valid) = {0:.2e}'.format(stats[-1, keys['error(valid)']]))
print('    final acc(train)   = {0:.2e}'.format(stats[-1, keys['acc(train)']]))
print('    final acc(valid)   = {0:.2e}'.format(stats[-1, keys['acc(valid)']]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

fig_1.savefig('SigmoidFig1.pdf')
fig_2.savefig('SigmoidFig2.pdf')

ac_final_errors_train.append(stats[-1, keys['error(train)']])
ac_final_errors_valid.append(stats[-1, keys['error(valid)']])
ac_final_accs_train.append(stats[-1, keys['acc(train)']])
ac_final_accs_valid.append(stats[-1, keys['acc(valid)']])
ac_final_run_times.append(run_time * 1. / num_epochs)
# Out:
# Epoch 1: 4.2s to complete
#     error(train)=1.81e-01, acc(train)=9.46e-01, error(valid)=1.76e-01, acc(valid)=9.50e-01
# Epoch 2: 3.3s to complete
#     error(train)=1.24e-01, acc(train)=9.63e-01, error(valid)=1.31e-01, acc(valid)=9.62e-01
# Epoch 3: 3.4s to complete
#     error(train)=9.40e-02, acc(train)=9.73e-01, error(valid)=1.12e-01, acc(valid)=9.68e-01
# Epoch 4: 3.3s to complete
#     error(train)=7.21e-02, acc(train)=9.79e-01, error(valid)=9.72e-02, acc(valid)=9.69e-01
# Epoch 5: 3.3s to complete
#     error(train)=5.48e-02, acc(train)=9.84e-01, error(valid)=8.87e-02, acc(valid)=9.74e-01
# Epoch 6: 3.3s to complete
#     error(train)=6.07e-02, acc(train)=9.81e-01, error(valid)=1.01e-01, acc(valid)=9.71e-01
# Epoch 7: 3.3s to complete
#     error(train)=3.84e-02, acc(train)=9.89e-01, error(valid)=8.00e-02, acc(valid)=9.74e-01
# Epoch 8: 3.3s to complete
#     error(train)=3.75e-02, acc(train)=9.89e-01, error(valid)=8.77e-02, acc(valid)=9.76e-01
# Epoch 9: 3.3s to complete
#     error(train)=3.13e-02, acc(train)=9.91e-01, error(valid)=8.61e-02, acc(valid)=9.76e-01
# Epoch 10: 3.4s to complete
#     error(train)=2.40e-02, acc(train)=9.94e-01, error(valid)=7.82e-02, acc(valid)=9.77e-01
# Epoch 11: 3.3s to complete
#     error(train)=1.83e-02, acc(train)=9.96e-01, error(valid)=7.97e-02, acc(valid)=9.76e-01
# Epoch 12: 3.3s to complete
#     error(train)=2.18e-02, acc(train)=9.94e-01, error(valid)=8.77e-02, acc(valid)=9.75e-01
# Epoch 13: 3.3s to complete
#     error(train)=1.76e-02, acc(train)=9.95e-01, error(valid)=8.24e-02, acc(valid)=9.77e-01
# Epoch 14: 3.4s to complete
#     error(train)=1.47e-02, acc(train)=9.96e-01, error(valid)=8.17e-02, acc(valid)=9.77e-01
# Epoch 15: 3.3s to complete
#     error(train)=1.10e-02, acc(train)=9.98e-01, error(valid)=7.75e-02, acc(valid)=9.79e-01
# Epoch 16: 3.3s to complete
#     error(train)=1.23e-02, acc(train)=9.97e-01, error(valid)=8.64e-02, acc(valid)=9.76e-01
# Epoch 17: 3.3s to complete
#     error(train)=7.53e-03, acc(train)=9.99e-01, error(valid)=8.07e-02, acc(valid)=9.79e-01
# Epoch 18: 3.3s to complete
#     error(train)=1.52e-02, acc(train)=9.96e-01, error(valid)=9.06e-02, acc(valid)=9.75e-01
# Epoch 19: 3.3s to complete
#     error(train)=6.26e-03, acc(train)=1.00e+00, error(valid)=8.08e-02, acc(valid)=9.80e-01
# Epoch 20: 3.3s to complete
#     error(train)=4.97e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.80e-01
# Epoch 21: 3.3s to complete
#     error(train)=4.88e-03, acc(train)=1.00e+00, error(valid)=8.18e-02, acc(valid)=9.78e-01
# Epoch 22: 3.3s to complete
#     error(train)=5.77e-03, acc(train)=9.99e-01, error(valid)=8.27e-02, acc(valid)=9.79e-01
# Epoch 23: 3.3s to complete
#     error(train)=4.00e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.79e-01
# Epoch 24: 3.5s to complete
#     error(train)=3.73e-03, acc(train)=1.00e+00, error(valid)=8.14e-02, acc(valid)=9.78e-01
# Epoch 25: 3.5s to complete
#     error(train)=3.28e-03, acc(train)=1.00e+00, error(valid)=8.03e-02, acc(valid)=9.80e-01
# Epoch 26: 3.4s to complete
#     error(train)=3.10e-03, acc(train)=1.00e+00, error(valid)=8.01e-02, acc(valid)=9.79e-01
# Epoch 27: 3.3s to complete
#     error(train)=3.08e-03, acc(train)=1.00e+00, error(valid)=8.22e-02, acc(valid)=9.80e-01
# Epoch 28: 3.3s to complete
#     error(train)=3.05e-03, acc(train)=1.00e+00, error(valid)=8.17e-02, acc(valid)=9.79e-01
# Epoch 29: 3.4s to complete
#     error(train)=2.88e-03, acc(train)=1.00e+00, error(valid)=7.95e-02, acc(valid)=9.79e-01
# Epoch 30: 3.3s to complete
#     error(train)=2.73e-03, acc(train)=1.00e+00, error(valid)=8.13e-02, acc(valid)=9.79e-01
# Epoch 31: 3.3s to complete
#     error(train)=2.75e-03, acc(train)=1.00e+00, error(valid)=8.02e-02, acc(valid)=9.79e-01
# Epoch 32: 3.3s to complete
#     error(train)=2.76e-03, acc(train)=1.00e+00, error(valid)=7.93e-02, acc(valid)=9.80e-01
# Epoch 33: 3.3s to complete
#     error(train)=2.92e-03, acc(train)=1.00e+00, error(valid)=8.36e-02, acc(valid)=9.79e-01
# Epoch 34: 3.3s to complete
#     error(train)=2.78e-03, acc(train)=1.00e+00, error(valid)=8.01e-02, acc(valid)=9.79e-01
# Epoch 35: 3.3s to complete
#     error(train)=2.56e-03, acc(train)=1.00e+00, error(valid)=8.03e-02, acc(valid)=9.80e-01
# Epoch 36: 3.3s to complete
#     error(train)=2.60e-03, acc(train)=1.00e+00, error(valid)=8.05e-02, acc(valid)=9.80e-01
# Epoch 37: 3.3s to complete
#     error(train)=2.56e-03, acc(train)=1.00e+00, error(valid)=8.00e-02, acc(valid)=9.79e-01
# Epoch 38: 3.3s to complete
#     error(train)=2.51e-03, acc(train)=1.00e+00, error(valid)=7.98e-02, acc(valid)=9.80e-01
# Epoch 39: 3.3s to complete
#     error(train)=2.66e-03, acc(train)=1.00e+00, error(valid)=8.15e-02, acc(valid)=9.79e-01
# Epoch 40: 3.3s to complete
#     error(train)=2.53e-03, acc(train)=1.00e+00, error(valid)=7.91e-02, acc(valid)=9.79e-01
# Epoch 41: 3.3s to complete
#     error(train)=2.44e-03, acc(train)=1.00e+00, error(valid)=8.01e-02, acc(valid)=9.80e-01
# Epoch 42: 3.3s to complete
#     error(train)=2.49e-03, acc(train)=1.00e+00, error(valid)=8.17e-02, acc(valid)=9.79e-01
# Epoch 43: 3.4s to complete
#     error(train)=2.44e-03, acc(train)=1.00e+00, error(valid)=8.00e-02, acc(valid)=9.79e-01
# Epoch 44: 3.3s to complete
#     error(train)=2.42e-03, acc(train)=1.00e+00, error(valid)=8.08e-02, acc(valid)=9.80e-01
# Epoch 45: 3.3s to complete
#     error(train)=2.63e-03, acc(train)=1.00e+00, error(valid)=8.04e-02, acc(valid)=9.80e-01
# Epoch 46: 3.3s to complete
#     error(train)=2.42e-03, acc(train)=1.00e+00, error(valid)=8.03e-02, acc(valid)=9.80e-01
# Epoch 47: 3.3s to complete
#     error(train)=2.44e-03, acc(train)=1.00e+00, error(valid)=8.02e-02, acc(valid)=9.80e-01
# Epoch 48: 3.3s to complete
#     error(train)=2.45e-03, acc(train)=1.00e+00, error(valid)=7.94e-02, acc(valid)=9.80e-01
# Epoch 49: 3.3s to complete
#     error(train)=2.39e-03, acc(train)=1.00e+00, error(valid)=7.95e-02, acc(valid)=9.80e-01
# Epoch 50: 3.3s to complete
#     error(train)=2.42e-03, acc(train)=1.00e+00, error(valid)=7.97e-02, acc(valid)=9.80e-01
# Epoch 51: 3.4s to complete
#     error(train)=2.43e-03, acc(train)=1.00e+00, error(valid)=8.03e-02, acc(valid)=9.80e-01
# Epoch 52: 3.3s to complete
#     error(train)=2.34e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.80e-01
# Epoch 53: 3.3s to complete
#     error(train)=2.36e-03, acc(train)=1.00e+00, error(valid)=7.92e-02, acc(valid)=9.79e-01
# Epoch 54: 3.3s to complete
#     error(train)=2.35e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.79e-01
# Epoch 55: 3.3s to complete
#     error(train)=2.45e-03, acc(train)=1.00e+00, error(valid)=8.00e-02, acc(valid)=9.80e-01
# Epoch 56: 3.2s to complete
#     error(train)=2.37e-03, acc(train)=1.00e+00, error(valid)=7.86e-02, acc(valid)=9.80e-01
# Epoch 57: 3.4s to complete
#     error(train)=2.37e-03, acc(train)=1.00e+00, error(valid)=7.84e-02, acc(valid)=9.80e-01
# Epoch 58: 3.3s to complete
#     error(train)=2.42e-03, acc(train)=1.00e+00, error(valid)=7.88e-02, acc(valid)=9.80e-01
# Epoch 59: 3.3s to complete
#     error(train)=2.36e-03, acc(train)=1.00e+00, error(valid)=7.97e-02, acc(valid)=9.80e-01
# Epoch 60: 3.3s to complete
#     error(train)=2.50e-03, acc(train)=1.00e+00, error(valid)=7.84e-02, acc(valid)=9.80e-01
# Epoch 61: 3.5s to complete
#     error(train)=2.35e-03, acc(train)=1.00e+00, error(valid)=7.77e-02, acc(valid)=9.80e-01
# Epoch 62: 4.2s to complete
#     error(train)=2.45e-03, acc(train)=1.00e+00, error(valid)=7.85e-02, acc(valid)=9.81e-01
# Epoch 63: 4.0s to complete
#     error(train)=2.36e-03, acc(train)=1.00e+00, error(valid)=7.84e-02, acc(valid)=9.80e-01
# Epoch 64: 4.2s to complete
#     error(train)=2.44e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.80e-01
# Epoch 65: 3.3s to complete
#     error(train)=2.90e-03, acc(train)=1.00e+00, error(valid)=8.02e-02, acc(valid)=9.79e-01
# Epoch 66: 3.3s to complete
#     error(train)=2.29e-03, acc(train)=1.00e+00, error(valid)=7.80e-02, acc(valid)=9.81e-01
# Epoch 67: 4.3s to complete
#     error(train)=2.33e-03, acc(train)=1.00e+00, error(valid)=7.86e-02, acc(valid)=9.80e-01
# Epoch 68: 3.6s to complete
#     error(train)=2.53e-03, acc(train)=1.00e+00, error(valid)=7.86e-02, acc(valid)=9.79e-01
# Epoch 69: 4.2s to complete
#     error(train)=2.36e-03, acc(train)=1.00e+00, error(valid)=7.75e-02, acc(valid)=9.80e-01
# Epoch 70: 3.9s to complete
#     error(train)=2.38e-03, acc(train)=1.00e+00, error(valid)=7.81e-02, acc(valid)=9.80e-01
# Epoch 71: 4.2s to complete
#     error(train)=2.51e-03, acc(train)=1.00e+00, error(valid)=7.84e-02, acc(valid)=9.80e-01
# Epoch 72: 4.2s to complete
#     error(train)=2.33e-03, acc(train)=1.00e+00, error(valid)=7.72e-02, acc(valid)=9.80e-01
# Epoch 73: 3.5s to complete
#     error(train)=2.39e-03, acc(train)=1.00e+00, error(valid)=7.98e-02, acc(valid)=9.80e-01
# Epoch 74: 3.8s to complete
#     error(train)=2.42e-03, acc(train)=1.00e+00, error(valid)=7.97e-02, acc(valid)=9.80e-01
# Epoch 75: 3.7s to complete
#     error(train)=2.38e-03, acc(train)=1.00e+00, error(valid)=7.97e-02, acc(valid)=9.80e-01
# Epoch 76: 3.5s to complete
#     error(train)=2.30e-03, acc(train)=1.00e+00, error(valid)=7.80e-02, acc(valid)=9.80e-01
# Epoch 77: 3.6s to complete
#     error(train)=2.36e-03, acc(train)=1.00e+00, error(valid)=7.74e-02, acc(valid)=9.80e-01
# Epoch 78: 3.4s to complete
#     error(train)=2.31e-03, acc(train)=1.00e+00, error(valid)=7.76e-02, acc(valid)=9.80e-01
# Epoch 79: 3.6s to complete
#     error(train)=2.37e-03, acc(train)=1.00e+00, error(valid)=7.99e-02, acc(valid)=9.81e-01
# Epoch 80: 3.9s to complete
#     error(train)=3.20e-03, acc(train)=1.00e+00, error(valid)=8.08e-02, acc(valid)=9.79e-01
# Epoch 81: 4.9s to complete
#     error(train)=2.32e-03, acc(train)=1.00e+00, error(valid)=7.85e-02, acc(valid)=9.80e-01
# Epoch 82: 5.3s to complete
#     error(train)=2.35e-03, acc(train)=1.00e+00, error(valid)=7.78e-02, acc(valid)=9.79e-01
# Epoch 83: 4.0s to complete
#     error(train)=2.38e-03, acc(train)=1.00e+00, error(valid)=7.79e-02, acc(valid)=9.79e-01
# Epoch 84: 4.5s to complete
#     error(train)=2.26e-03, acc(train)=1.00e+00, error(valid)=7.73e-02, acc(valid)=9.81e-01
# Epoch 85: 3.9s to complete
#     error(train)=2.39e-03, acc(train)=1.00e+00, error(valid)=7.84e-02, acc(valid)=9.80e-01
# Epoch 86: 3.8s to complete
#     error(train)=2.28e-03, acc(train)=1.00e+00, error(valid)=7.71e-02, acc(valid)=9.80e-01
# Epoch 87: 4.2s to complete
#     error(train)=2.27e-03, acc(train)=1.00e+00, error(valid)=7.72e-02, acc(valid)=9.80e-01
# Epoch 88: 4.6s to complete
#     error(train)=2.28e-03, acc(train)=1.00e+00, error(valid)=7.71e-02, acc(valid)=9.80e-01
# Epoch 89: 4.0s to complete
#     error(train)=2.41e-03, acc(train)=1.00e+00, error(valid)=7.83e-02, acc(valid)=9.80e-01
# Epoch 90: 3.8s to complete
#     error(train)=2.27e-03, acc(train)=1.00e+00, error(valid)=7.71e-02, acc(valid)=9.81e-01
# Epoch 91: 3.7s to complete
#     error(train)=2.33e-03, acc(train)=1.00e+00, error(valid)=7.72e-02, acc(valid)=9.80e-01
# Epoch 92: 3.8s to complete
#     error(train)=2.20e-03, acc(train)=1.00e+00, error(valid)=7.75e-02, acc(valid)=9.80e-01
# Epoch 93: 3.8s to complete
#     error(train)=2.39e-03, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.79e-01
# Epoch 94: 3.7s to complete
#     error(train)=2.26e-03, acc(train)=1.00e+00, error(valid)=7.67e-02, acc(valid)=9.81e-01
# Epoch 95: 3.9s to complete
#     error(train)=2.34e-03, acc(train)=1.00e+00, error(valid)=7.67e-02, acc(valid)=9.80e-01
# Epoch 96: 3.7s to complete
#     error(train)=2.24e-03, acc(train)=1.00e+00, error(valid)=7.72e-02, acc(valid)=9.81e-01
# Epoch 97: 3.9s to complete
#     error(train)=2.37e-03, acc(train)=1.00e+00, error(valid)=7.62e-02, acc(valid)=9.80e-01
# Epoch 98: 3.8s to complete
#     error(train)=2.30e-03, acc(train)=1.00e+00, error(valid)=7.64e-02, acc(valid)=9.80e-01
# Epoch 99: 3.8s to complete
#     error(train)=2.44e-03, acc(train)=1.00e+00, error(valid)=7.79e-02, acc(valid)=9.80e-01
# Epoch 100: 3.8s to complete
#     error(train)=2.26e-03, acc(train)=1.00e+00, error(valid)=7.62e-02, acc(valid)=9.81e-01
#     final error(train) = 2.26e-03
#     final error(valid) = 7.62e-02
#     final acc(train)   = 1.00e+00
#     final acc(valid)   = 9.81e-01
#     run time per epoch = 4.93

# %%
#setup hyperparameters

weights_penalty=L2Penalty(0.01)

learning_rate = 0.01
momentum_coef = 0.9
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init,weights_penalty=weights_penalty), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init,weights_penalty=weights_penalty)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = MomentumLearningRule(learning_rate=learning_rate, mom_coeff=momentum_coef)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval)

regu_data.append([stats, keys, run_time, fig_1, ax_1, fig_2, ax_2])

print('    final error(train) = {0:.2e}'.format(stats[-1, keys['error(train)']]))
print('    final error(valid) = {0:.2e}'.format(stats[-1, keys['error(valid)']]))
print('    final acc(train)   = {0:.2e}'.format(stats[-1, keys['acc(train)']]))
print('    final acc(valid)   = {0:.2e}'.format(stats[-1, keys['acc(valid)']]))
print('    run time per epoch = {0:.2f}'.format(run_time * 1. / num_epochs))

fig_1.savefig('SigmoidFig1.pdf')
fig_2.savefig('SigmoidFig2.pdf')

ac_final_errors_train.append(stats[-1, keys['error(train)']])
ac_final_errors_valid.append(stats[-1, keys['error(valid)']])
ac_final_accs_train.append(stats[-1, keys['acc(train)']])
ac_final_accs_valid.append(stats[-1, keys['acc(valid)']])
ac_final_run_times.append(run_time * 1. / num_epochs)
# Out:
# Epoch 1: 3.9s to complete
#     error(train)=2.79e-01, acc(train)=9.26e-01, error(valid)=2.59e-01, acc(valid)=9.31e-01
# Epoch 2: 3.9s to complete
#     error(train)=2.44e-01, acc(train)=9.37e-01, error(valid)=2.29e-01, acc(valid)=9.45e-01
# Epoch 3: 3.8s to complete
#     error(train)=2.51e-01, acc(train)=9.32e-01, error(valid)=2.37e-01, acc(valid)=9.35e-01
# Epoch 4: 3.8s to complete
#     error(train)=2.31e-01, acc(train)=9.39e-01, error(valid)=2.18e-01, acc(valid)=9.44e-01
# Epoch 5: 3.8s to complete
#     error(train)=2.34e-01, acc(train)=9.40e-01, error(valid)=2.21e-01, acc(valid)=9.46e-01
# Epoch 6: 3.8s to complete
#     error(train)=2.21e-01, acc(train)=9.43e-01, error(valid)=2.08e-01, acc(valid)=9.49e-01
# Epoch 7: 4.0s to complete
#     error(train)=2.23e-01, acc(train)=9.44e-01, error(valid)=2.12e-01, acc(valid)=9.49e-01
# Epoch 8: 3.7s to complete
#     error(train)=2.23e-01, acc(train)=9.44e-01, error(valid)=2.10e-01, acc(valid)=9.48e-01
# Epoch 9: 3.8s to complete
#     error(train)=2.19e-01, acc(train)=9.45e-01, error(valid)=2.06e-01, acc(valid)=9.51e-01
# Epoch 10: 3.8s to complete
#     error(train)=2.26e-01, acc(train)=9.44e-01, error(valid)=2.12e-01, acc(valid)=9.47e-01
# Epoch 11: 3.8s to complete
#     error(train)=2.26e-01, acc(train)=9.41e-01, error(valid)=2.12e-01, acc(valid)=9.47e-01
# Epoch 12: 3.8s to complete
#     error(train)=2.24e-01, acc(train)=9.45e-01, error(valid)=2.11e-01, acc(valid)=9.47e-01
# Epoch 13: 3.8s to complete
#     error(train)=2.14e-01, acc(train)=9.47e-01, error(valid)=2.03e-01, acc(valid)=9.51e-01
# Epoch 14: 3.8s to complete
#     error(train)=2.14e-01, acc(train)=9.46e-01, error(valid)=2.02e-01, acc(valid)=9.51e-01
# Epoch 15: 4.2s to complete
#     error(train)=2.08e-01, acc(train)=9.51e-01, error(valid)=1.95e-01, acc(valid)=9.55e-01
# Epoch 16: 4.1s to complete
#     error(train)=2.12e-01, acc(train)=9.46e-01, error(valid)=1.99e-01, acc(valid)=9.52e-01
# Epoch 17: 4.4s to complete
#     error(train)=2.10e-01, acc(train)=9.47e-01, error(valid)=1.95e-01, acc(valid)=9.54e-01
# Epoch 18: 4.4s to complete
#     error(train)=2.17e-01, acc(train)=9.43e-01, error(valid)=2.06e-01, acc(valid)=9.46e-01
# Epoch 19: 4.4s to complete
#     error(train)=2.15e-01, acc(train)=9.48e-01, error(valid)=2.02e-01, acc(valid)=9.53e-01
# Epoch 20: 3.9s to complete
#     error(train)=2.15e-01, acc(train)=9.47e-01, error(valid)=2.04e-01, acc(valid)=9.50e-01
# Epoch 21: 3.8s to complete
#     error(train)=2.12e-01, acc(train)=9.47e-01, error(valid)=2.01e-01, acc(valid)=9.49e-01
# Epoch 22: 3.9s to complete
#     error(train)=2.09e-01, acc(train)=9.47e-01, error(valid)=1.97e-01, acc(valid)=9.52e-01
# Epoch 23: 4.0s to complete
#     error(train)=2.17e-01, acc(train)=9.45e-01, error(valid)=2.03e-01, acc(valid)=9.51e-01
# Epoch 24: 3.8s to complete
#     error(train)=2.08e-01, acc(train)=9.47e-01, error(valid)=1.98e-01, acc(valid)=9.51e-01
# Epoch 25: 3.8s to complete
#     error(train)=2.14e-01, acc(train)=9.47e-01, error(valid)=2.02e-01, acc(valid)=9.49e-01
# Epoch 26: 3.9s to complete
#     error(train)=2.17e-01, acc(train)=9.43e-01, error(valid)=2.02e-01, acc(valid)=9.49e-01
# Epoch 27: 3.9s to complete
#     error(train)=2.12e-01, acc(train)=9.45e-01, error(valid)=1.98e-01, acc(valid)=9.51e-01
# Epoch 28: 3.7s to complete
#     error(train)=2.10e-01, acc(train)=9.49e-01, error(valid)=1.99e-01, acc(valid)=9.53e-01
# Epoch 29: 3.8s to complete
#     error(train)=2.09e-01, acc(train)=9.48e-01, error(valid)=1.96e-01, acc(valid)=9.54e-01
# Epoch 30: 3.8s to complete
#     error(train)=2.02e-01, acc(train)=9.50e-01, error(valid)=1.93e-01, acc(valid)=9.53e-01
# Epoch 31: 3.8s to complete
#     error(train)=2.04e-01, acc(train)=9.50e-01, error(valid)=1.93e-01, acc(valid)=9.53e-01
# Epoch 32: 3.8s to complete
#     error(train)=2.05e-01, acc(train)=9.50e-01, error(valid)=1.96e-01, acc(valid)=9.54e-01
# Epoch 33: 3.8s to complete
#     error(train)=2.13e-01, acc(train)=9.45e-01, error(valid)=2.04e-01, acc(valid)=9.50e-01
# Epoch 34: 4.1s to complete
#     error(train)=2.10e-01, acc(train)=9.49e-01, error(valid)=2.01e-01, acc(valid)=9.52e-01
# Epoch 35: 4.3s to complete
#     error(train)=2.03e-01, acc(train)=9.50e-01, error(valid)=1.93e-01, acc(valid)=9.53e-01
# Epoch 36: 3.9s to complete
#     error(train)=2.10e-01, acc(train)=9.48e-01, error(valid)=1.98e-01, acc(valid)=9.52e-01
# Epoch 37: 3.8s to complete
#     error(train)=2.05e-01, acc(train)=9.49e-01, error(valid)=1.95e-01, acc(valid)=9.52e-01
# Epoch 38: 3.7s to complete
#     error(train)=2.04e-01, acc(train)=9.51e-01, error(valid)=1.92e-01, acc(valid)=9.54e-01
# Epoch 39: 3.9s to complete
#     error(train)=2.14e-01, acc(train)=9.44e-01, error(valid)=2.01e-01, acc(valid)=9.49e-01
# Epoch 40: 3.8s to complete
#     error(train)=2.03e-01, acc(train)=9.50e-01, error(valid)=1.91e-01, acc(valid)=9.54e-01
# Epoch 41: 3.8s to complete
#     error(train)=2.29e-01, acc(train)=9.39e-01, error(valid)=2.18e-01, acc(valid)=9.42e-01
# Epoch 42: 3.8s to complete
#     error(train)=1.98e-01, acc(train)=9.52e-01, error(valid)=1.89e-01, acc(valid)=9.55e-01
# Epoch 43: 3.8s to complete
#     error(train)=2.09e-01, acc(train)=9.50e-01, error(valid)=1.95e-01, acc(valid)=9.54e-01
# Epoch 44: 3.8s to complete
#     error(train)=2.11e-01, acc(train)=9.50e-01, error(valid)=2.00e-01, acc(valid)=9.54e-01
# Epoch 45: 3.9s to complete
#     error(train)=2.10e-01, acc(train)=9.46e-01, error(valid)=1.96e-01, acc(valid)=9.49e-01
# Epoch 46: 3.8s to complete
#     error(train)=2.04e-01, acc(train)=9.49e-01, error(valid)=1.93e-01, acc(valid)=9.55e-01
# Epoch 47: 4.1s to complete
#     error(train)=2.10e-01, acc(train)=9.48e-01, error(valid)=1.99e-01, acc(valid)=9.52e-01
# Epoch 48: 4.1s to complete
#     error(train)=2.01e-01, acc(train)=9.50e-01, error(valid)=1.90e-01, acc(valid)=9.55e-01
# Epoch 49: 4.0s to complete
#     error(train)=2.08e-01, acc(train)=9.46e-01, error(valid)=1.96e-01, acc(valid)=9.49e-01
# Epoch 50: 4.1s to complete
#     error(train)=1.99e-01, acc(train)=9.50e-01, error(valid)=1.89e-01, acc(valid)=9.54e-01
# Epoch 51: 4.0s to complete
#     error(train)=2.05e-01, acc(train)=9.50e-01, error(valid)=1.95e-01, acc(valid)=9.52e-01
# Epoch 52: 3.9s to complete
#     error(train)=2.06e-01, acc(train)=9.49e-01, error(valid)=1.94e-01, acc(valid)=9.54e-01
# Epoch 53: 3.9s to complete
#     error(train)=2.08e-01, acc(train)=9.47e-01, error(valid)=1.96e-01, acc(valid)=9.51e-01
# Epoch 54: 3.8s to complete
#     error(train)=2.05e-01, acc(train)=9.49e-01, error(valid)=1.96e-01, acc(valid)=9.53e-01
# Epoch 55: 3.8s to complete
#     error(train)=2.06e-01, acc(train)=9.50e-01, error(valid)=1.94e-01, acc(valid)=9.55e-01
# Epoch 56: 4.0s to complete
#     error(train)=2.05e-01, acc(train)=9.50e-01, error(valid)=1.93e-01, acc(valid)=9.54e-01
# Epoch 57: 3.8s to complete
#     error(train)=2.03e-01, acc(train)=9.52e-01, error(valid)=1.91e-01, acc(valid)=9.56e-01
# Epoch 58: 3.8s to complete
#     error(train)=2.05e-01, acc(train)=9.50e-01, error(valid)=1.97e-01, acc(valid)=9.51e-01
# Epoch 59: 3.9s to complete
#     error(train)=2.07e-01, acc(train)=9.49e-01, error(valid)=1.94e-01, acc(valid)=9.54e-01
# Epoch 60: 4.1s to complete
#     error(train)=2.03e-01, acc(train)=9.51e-01, error(valid)=1.92e-01, acc(valid)=9.56e-01
# Epoch 61: 3.9s to complete
#     error(train)=2.00e-01, acc(train)=9.53e-01, error(valid)=1.88e-01, acc(valid)=9.56e-01
# Epoch 62: 3.9s to complete
#     error(train)=2.02e-01, acc(train)=9.49e-01, error(valid)=1.89e-01, acc(valid)=9.54e-01
# Epoch 63: 3.9s to complete
#     error(train)=2.01e-01, acc(train)=9.52e-01, error(valid)=1.91e-01, acc(valid)=9.55e-01
# Epoch 64: 4.0s to complete
#     error(train)=1.98e-01, acc(train)=9.51e-01, error(valid)=1.89e-01, acc(valid)=9.54e-01
# Epoch 65: 3.9s to complete
#     error(train)=2.15e-01, acc(train)=9.47e-01, error(valid)=1.99e-01, acc(valid)=9.52e-01
# Epoch 66: 3.9s to complete
#     error(train)=2.08e-01, acc(train)=9.49e-01, error(valid)=1.96e-01, acc(valid)=9.52e-01
# Epoch 67: 3.9s to complete
#     error(train)=2.12e-01, acc(train)=9.50e-01, error(valid)=1.99e-01, acc(valid)=9.54e-01
# Epoch 68: 4.2s to complete
#     error(train)=2.07e-01, acc(train)=9.48e-01, error(valid)=1.95e-01, acc(valid)=9.52e-01
# Epoch 69: 4.3s to complete
#     error(train)=2.12e-01, acc(train)=9.47e-01, error(valid)=2.01e-01, acc(valid)=9.49e-01
# Epoch 70: 4.1s to complete
#     error(train)=2.02e-01, acc(train)=9.50e-01, error(valid)=1.91e-01, acc(valid)=9.54e-01
# Epoch 71: 4.4s to complete
#     error(train)=2.03e-01, acc(train)=9.51e-01, error(valid)=1.89e-01, acc(valid)=9.56e-01
# Epoch 72: 4.1s to complete
#     error(train)=2.03e-01, acc(train)=9.51e-01, error(valid)=1.93e-01, acc(valid)=9.54e-01
# Epoch 73: 4.2s to complete
#     error(train)=2.02e-01, acc(train)=9.50e-01, error(valid)=1.92e-01, acc(valid)=9.54e-01
# Epoch 74: 3.9s to complete
#     error(train)=2.01e-01, acc(train)=9.53e-01, error(valid)=1.91e-01, acc(valid)=9.56e-01
# Epoch 75: 3.8s to complete
#     error(train)=2.04e-01, acc(train)=9.50e-01, error(valid)=1.92e-01, acc(valid)=9.54e-01
# Epoch 76: 4.0s to complete
#     error(train)=2.06e-01, acc(train)=9.48e-01, error(valid)=1.96e-01, acc(valid)=9.52e-01
# Epoch 77: 3.9s to complete
#     error(train)=2.17e-01, acc(train)=9.46e-01, error(valid)=2.04e-01, acc(valid)=9.50e-01
# Epoch 78: 3.7s to complete
#     error(train)=2.09e-01, acc(train)=9.48e-01, error(valid)=1.98e-01, acc(valid)=9.51e-01
# Epoch 79: 3.8s to complete
#     error(train)=2.02e-01, acc(train)=9.51e-01, error(valid)=1.91e-01, acc(valid)=9.54e-01
# Epoch 80: 4.2s to complete
#     error(train)=2.11e-01, acc(train)=9.46e-01, error(valid)=1.98e-01, acc(valid)=9.51e-01
# Epoch 81: 4.3s to complete
#     error(train)=2.04e-01, acc(train)=9.51e-01, error(valid)=1.93e-01, acc(valid)=9.54e-01
# Epoch 82: 3.8s to complete
#     error(train)=2.01e-01, acc(train)=9.51e-01, error(valid)=1.92e-01, acc(valid)=9.55e-01
# Epoch 83: 4.0s to complete
#     error(train)=2.08e-01, acc(train)=9.48e-01, error(valid)=1.97e-01, acc(valid)=9.53e-01
# Epoch 84: 4.0s to complete
#     error(train)=2.08e-01, acc(train)=9.46e-01, error(valid)=1.98e-01, acc(valid)=9.49e-01
# Epoch 85: 3.7s to complete
#     error(train)=2.06e-01, acc(train)=9.48e-01, error(valid)=1.97e-01, acc(valid)=9.54e-01
# Epoch 86: 3.9s to complete
#     error(train)=1.99e-01, acc(train)=9.50e-01, error(valid)=1.88e-01, acc(valid)=9.56e-01
# Epoch 87: 3.8s to complete
#     error(train)=2.06e-01, acc(train)=9.51e-01, error(valid)=1.95e-01, acc(valid)=9.55e-01
# Epoch 88: 3.7s to complete
#     error(train)=2.02e-01, acc(train)=9.49e-01, error(valid)=1.90e-01, acc(valid)=9.54e-01
# Epoch 89: 3.9s to complete
#     error(train)=2.03e-01, acc(train)=9.51e-01, error(valid)=1.93e-01, acc(valid)=9.54e-01
# Epoch 90: 3.8s to complete
#     error(train)=2.00e-01, acc(train)=9.51e-01, error(valid)=1.89e-01, acc(valid)=9.57e-01
# Epoch 91: 3.8s to complete
#     error(train)=2.08e-01, acc(train)=9.47e-01, error(valid)=1.97e-01, acc(valid)=9.51e-01
# Epoch 92: 3.8s to complete
#     error(train)=2.03e-01, acc(train)=9.50e-01, error(valid)=1.93e-01, acc(valid)=9.53e-01
# Epoch 93: 3.9s to complete
#     error(train)=2.04e-01, acc(train)=9.48e-01, error(valid)=1.95e-01, acc(valid)=9.52e-01
# Epoch 94: 3.7s to complete
#     error(train)=2.03e-01, acc(train)=9.52e-01, error(valid)=1.90e-01, acc(valid)=9.55e-01
# Epoch 95: 4.2s to complete
#     error(train)=2.16e-01, acc(train)=9.45e-01, error(valid)=2.05e-01, acc(valid)=9.47e-01
# Epoch 96: 4.0s to complete
#     error(train)=2.02e-01, acc(train)=9.51e-01, error(valid)=1.90e-01, acc(valid)=9.55e-01
# Epoch 97: 3.8s to complete
#     error(train)=2.03e-01, acc(train)=9.52e-01, error(valid)=1.93e-01, acc(valid)=9.57e-01
# Epoch 98: 3.8s to complete
#     error(train)=2.10e-01, acc(train)=9.47e-01, error(valid)=1.98e-01, acc(valid)=9.51e-01
# Epoch 99: 3.9s to complete
#     error(train)=2.01e-01, acc(train)=9.51e-01, error(valid)=1.90e-01, acc(valid)=9.56e-01
# Epoch 100: 3.8s to complete
#     error(train)=2.01e-01, acc(train)=9.49e-01, error(valid)=1.92e-01, acc(valid)=9.52e-01
#     final error(train) = 2.01e-01
#     final error(valid) = 1.92e-01
#     final acc(train)   = 9.49e-01
#     final acc(valid)   = 9.52e-01
#     run time per epoch = 5.31

# %%
layers = range(1,7)
i=0
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111)
for stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 in regu_data:       
# Plot the change in the validation and training set accuracy over training.
    ax.plot(np.arange(1, stats.shape[0]) * stats_interval, 
        stats[1:, keys['error(valid)']], label=layers[i])
    i += 1
    
ax.set_title('Accuracy on validation set of different Activation functions')    
ax.legend(loc=0)
ax.set_xlabel('Epoch number')
# Out:
# Text(0.5,0,'Epoch number')

# %%
layers = range(3,9)
i=0

fig_1 = plt.figure(figsize=(12, 6))
ax_1 = fig_1.add_subplot(111)
fig_2 = plt.figure(figsize=(12, 6))
ax_2 = fig_2.add_subplot(111)


for stats, keys, run_time, a, b, c, d in regu_data:       
# Plot the change in the validation and training set accuracy over training.
    ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
        stats[1:, keys['error(train)']], label='{0} test'.format(layers[i]))
    ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
        stats[1:, keys['error(valid)']], label='{0} test'.format(layers[i]))
    i += 1
    
#ax.set_title('Accuracy on validation set of different layered LeakyRelu Model')    
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number')

ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number')

#fig.savefig('All_Layers.pdf')
# Out:
# Text(0.5,0,'Epoch number')

# %% [markdown]
# Plot the training set error against epoch number for all different regularisation schemes on the same axis. On a second axis plot the validation set error against epoch number for all the different regularisation schemes. Interpret and comment on what you see.

# %% [markdown]
# The cell below defines two functions for visualising the first layer weights of the models trained above. The first plots a histogram of the weight values and the second plots the first layer weights as feature maps, i.e. each row of the first layer weight matrix (corresponding to the weights going from the input MNIST image to a particular first layer output) is visualised as a $28\times 28$ image. In these feature maps white corresponds to negative weights, black to positive weights and grey to weights close to zero.
#
# Use these functions to plot a histogram and feature map visualisation for the first layer weights of each model trained above. You should try to interpret the plots in the context of what you were told in the lecture about the behaviour of L1 versus L2 regularisation.

# %%
def plot_param_histogram(param, fig_size=(6, 3), interval=[-1.5, 1.5]):
    """Plots a normalised histogram of an array of parameter values."""
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot(111)
    ax.hist(param.flatten(), 50, interval, normed=True)
    ax.set_xlabel('Parameter value')
    ax.set_ylabel('Normalised frequency density')
    return fig, ax

def visualise_first_layer_weights(weights, fig_size=(5, 5)):
    """Plots a grid of first layer weights as feature maps."""
    fig = plt.figure(figsize=fig_size)
    num_feature_maps = weights.shape[0]
    grid_size = int(num_feature_maps**0.5)
    max_abs = np.abs(model.params[0]).max()
    tiled = -np.ones((30 * grid_size, 
                      30 * num_feature_maps // grid_size)) * max_abs
    for i, fm in enumerate(model.params[0]):
        r, c = i % grid_size, i // grid_size
        tiled[1 + r * 30:(r + 1) * 30 - 1, 
              1 + c * 30:(c + 1) * 30 - 1] = fm.reshape((28, 28))
    ax = fig.add_subplot(111)
    max_abs = np.abs(tiled).max()
    ax.imshow(tiled, cmap='Greys', vmin=-max_abs, vmax=max_abs)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

# %% [markdown]
# ## Exercise 4: Random data augmentation
#
# Another technique mentioned in the lectures for trying to reduce overfitting is to artificially augment the training data set by performing random transformations to the original training data inputs. The idea is to produce further artificial inputs corresponding to the same target class as the original input. The closer the artificially generated inputs are to the appearing like the true inputs the better as they provide more realistic additional examples for the model to learn from.
#
# For the handwritten image inputs in the MNIST dataset, an obvious way to considering augmenting the dataset is to apply small rotations to the original images. Providing the rotations are small we would generally expect that what we would identify as the class of a digit image will remain the same.
#
# Implement a function which given a batch of MNIST images as 784-dimensional vectors, i.e. an array of shape `(batch_size, 784)`
#
#   * chooses 25% of the images in the batch at random
#   * for each image in the 25% chosen, rotates the image by a random angle in $\left[-30^\circ,\,30^\circ\right]$
#   * returns a new array of size `(batch_size, 784)` in which the rows corresponding to the 25% chosen images are the vectors corresponding to the new randomly rotated images, while the remaining rows correspond to the original images.
#
# You will need to make use of the [`scipy.ndimage.interpolation.rotate`](https://docs.scipy.org/doc/scipy-0.16.0/reference/generated/scipy.ndimage.interpolation.rotate.html#scipy.ndimage.interpolation.rotate) function which is imported below for you. For computational efficiency you should use bilinear interpolation by setting `order=1` as a keyword argument to this function rather than using the default of bicubic interpolation. Additionally you should make sure the original shape of the images is maintained by passing a `reshape=False` keyword argument.

# %%
from scipy.ndimage.interpolation import rotate

def random_rotation(inputs, rng):
    """Randomly rotates a subset of images in a batch.
    
    Args:
        inputs: Input image batch, an array of shape (batch_size, 784).
        rng: A seeded random number generator.
        
    Returns:
        An array of shape (batch_size, 784) corresponding to a copy
        of the original `inputs` array with the randomly selected
        images rotated by a random angle. The original `inputs`
        array should not be modified.
    """
    raise NotImplementedError()

# %% [markdown]
# Use the cell below to test your implementation. This uses the `show_batch_of_images` function we implemented in the first lab notebook to visualise the images in a batch before and after application of the random rotation transformation.

# %%
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
def show_batch_of_images(img_batch, fig_size=(3, 3)):
    fig = plt.figure(figsize=fig_size)
    batch_size, im_height, im_width = img_batch.shape
    # calculate no. columns per grid row to give square grid
    grid_size = int(batch_size**0.5)
    # intialise empty array to tile image grid into
    tiled = np.empty((im_height * grid_size, 
                      im_width * batch_size // grid_size))
    # iterate over images in batch + indexes within batch
    for i, img in enumerate(img_batch):
        # calculate grid row and column indices
        r, c = i % grid_size, i // grid_size
        tiled[r * im_height:(r + 1) * im_height, 
              c * im_height:(c + 1) * im_height] = img
    ax = fig.add_subplot(111)
    ax.imshow(tiled, cmap='Greys') #, vmin=0., vmax=1.)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

test_data = MNISTDataProvider('test', 100, rng=rng)
inputs, targets = test_data.next()
_ = show_batch_of_images(inputs.reshape((-1, 28, 28)))
transformed_inputs = random_rotation(inputs, rng)
_ = show_batch_of_images(transformed_inputs.reshape((-1, 28, 28)))

# %% [markdown]
# ## Exercise 5: Training with data augmentation
#
# One simple way to use data augmentation is to just statically augment the training data set - for example we could iterate through the training dataset applying a transformation function like that implemented above to generate new artificial inputs, and use both the original and newly generated data in a new data provider object. We are quite limited however in how far we can augment the dataset by with a static method like this however - if we wanted to apply 9 random rotations to each image in the original datase, we would end up with a dataset with 10 times the memory requirements and that would take 10 times as long to run through each epoch.
#
# An alternative is to randomly augment the data on the fly as we iterate through the data provider in each epoch. In this method a new data provider class can be defined that inherits from the original data provider to be augmented, and provides a new `next` method which applies a random transformation function like that implemented in the previous exercise to each input batch before returning it. This method means that on every epoch a different set of training examples are provided to the model and so in some ways corresponds to an 'infinite' data set (although the amount of variability in the dataset will still be significantly less than the variability in all possible digit images). Compared to static augmentation, this dynamic augmentation scheme comes at the computational cost of having to apply the random transformation each time a new batch is provided. We can vary this overhead by changing the proportion of images in a batch randomly transformed.
#
# An implementation of this scheme has been provided for the MNIST data set in the `AugmentedMNISTDataProvider` object in the `mlp.data_providers` module. In addition to the arguments of the original `MNISTDataProvider.__init__` method, this additional takes a `transformer` argument, which should be a function which takes as arguments an inputs batch array and a random number generator object, and returns an array corresponding to a random transformation of the inputs.
#
# Train a model with the same architecture as in exercise 3 and with no L1 / L2 regularisation using a training data provider which randomly augments the training images using your `random_rotation` transformer function. Plot the training and validation set errors over the training epochs and compare this plot to your previous results from exercise 3.

# %%
from mlp.data_providers import AugmentedMNISTDataProvider

aug_train_data = AugmentedMNISTDataProvider('train', rng=rng, transformer=random_rotation)
